# %%
from pubg_python import PUBG, Shard
import requests
import pandas as pd

api = PUBG('eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJqdGkiOiI4ZjQ2OWY0MC00ZjNmLTAxMzgtODRmZS0yM2Y5YzdiZjFmM2IiLCJpc3MiOiJnYW1lbG9ja2VyIiwiaWF0IjoxNTg0OTczMzEwLCJwdWIiOiJibHVlaG9sZSIsInRpdGxlIjoicHViZyIsImFwcCI6InZhbGVyaWktZ2luYWstIn0.rU8dkZPW-oqjYA8b3hitbyRUdgfujaEQK-MIT5w-78Q', Shard.STEAM)

# %%
from chicken_dinner.pubgapi import PUBG

# %%
headers = {
    "Authorization": f'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJqdGkiOiI4ZjQ2OWY0MC00ZjNmLTAxMzgtODRmZS0yM2Y5YzdiZjFmM2IiLCJpc3MiOiJnYW1lbG9ja2VyIiwiaWF0IjoxNTg0OTczMzEwLCJwdWIiOiJibHVlaG9sZSIsInRpdGxlIjoicHViZyIsImFwcCI6InZhbGVyaWktZ2luYWstIn0.rU8dkZPW-oqjYA8b3hitbyRUdgfujaEQK-MIT5w-78Q',
    "Accept": "application/vnd.api+json"
}

# %% [markdown]
# Retrieving sample of Match IDS

# %%
match_id=[]
sample = api.samples().get()
for match in sample.matches:
    match_id.append(match.id)
    print (match_id)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# Retrieving one Match Data by ID

# %%
url_collectassetsid = f"https://api.pubg.com/shards/EU/matches/{match_id[4]}"
response2 = requests.get(url_collectassetsid, headers=headers)

# %%
response2.json()
# Out:
# {'data': {'type': 'match',
#   'id': '2dc9cdb8-3a46-4429-a166-cb4edee32a7b',
#   'attributes': {'createdAt': '2020-04-04T00:13:44Z',
#    'stats': None,
#    'gameMode': 'squad',
#    'shardId': 'steam',
#    'tags': None,
#    'isCustomMatch': False,
#    'matchType': 'official',
#    'duration': 1015,
#    'titleId': 'bluehole-pubg',
#    'mapName': 'Summerland_Main',
#    'seasonState': 'progress'},
#   'relationships': {'rosters': {'data': [{'type': 'roster',
#       'id': 'ebefd4f8-cc97-4ba1-8399-35b7dd111ba4'},
#      {'type': 'roster', 'id': '6b94d71e-040f-4907-8e9d-33485592ccd5'},
#      {'type': 'roster', 'id': '6e2f1988-e33a-4b73-90b7-abf1de3069e6'},
#      {'type': 'roster', 'id': 'f09fc90a-f7cd-45d3-b636-fed188841fb5'},
#      {'type': 'roster', 'id': '23a367e4-5b64-4abd-981e-fd1205f29372'},
#      {'type': 'roster', 'id': '7b9f3fac-b34b-4807-b0c6-93b9d8aa883a'},
#      {'type': 'roster', 'id': 'b7a70d4a-fb2d-4e86-9a01-54288012c0b8'},
# ...

# %%
t_url="https://telemetry-cdn.playbattlegrounds.com/bluehole-pubg/steam/2020/04/04/00/32/c80c1458-760b-11ea-9fd5-8eedea546dda-telemetry.json"

# %%
response3 = requests.get(t_url, headers=headers)

# %%
telemetry=response3.json()

# %%
telemetry=json.dumps(telemetry)

# %%
json_data = []
for i in response3.json():
    if (i["_T"] == "LogPlayerPosition") or (i["_T"] == "LogParachuteLanding"):
        json_data.append(i)
json_data
# Out:
# [{'character': {'name': 'AwesomeGarfi',
#    'teamId': 4,
#    'health': 100,
#    'location': {'x': 137763.28125, 'y': 55902.640625, 'z': 690.8999633789062},
#    'ranking': 0,
#    'accountId': 'account.226eb740251a4cc29c599c80f50338da',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'vehicle': None,
#   'elapsedTime': 0,
#   'numAlivePlayers': 59,
#   'common': {'isGame': 0},
#   '_D': '2020-04-04T00:12:52.448Z',
#   '_T': 'LogPlayerPosition'},
#  {'character': {'name': 'hgqhq666',
#    'teamId': 2,
#    'health': 100,
#    'location': {'x': 155942.40625, 'y': 156149.90625, 'z': 690.1507568359375},
#    'ranking': 0,
#    'accountId': 'account.152c19dec2cf4f9284d1ca80e11979cc',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'vehicle': None,
#   'elapsedTime': 0,
#   'numAlivePlayers': 59,
#   'common': {'isGame': 0},
#   '_D': '2020-04-04T00:12:52.448Z',
#   '_T': 'LogPlayerPosition'},
# ...

# %%
data=pd.read_json(json.dumps(json_data))
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2984 entries, 0 to 2983
# Data columns (total 8 columns):
# _D                 2984 non-null object
# _T                 2984 non-null object
# character          2984 non-null object
# common             2984 non-null object
# distance           48 non-null float64
# elapsedTime        2936 non-null float64
# numAlivePlayers    2936 non-null float64
# vehicle            103 non-null object
# dtypes: float64(3), object(5)
# memory usage: 186.6+ KB

# %%
data['character'][1]
# Out:
# {'name': 'hgqhq666',
#  'teamId': 2,
#  'health': 100,
#  'location': {'x': 155942.40625, 'y': 156149.90625, 'z': 690.1507568359375},
#  'ranking': 0,
#  'accountId': 'account.152c19dec2cf4f9284d1ca80e11979cc',
#  'isInBlueZone': False,
#  'isInRedZone': False,
#  'zone': []}

# %%
from pandas.io.json import json_normalize
df2 = json_normalize(data['character'])
df3=json_normalize(data['common'])

# %%
data=data.drop(['character','common'],axis=1)

# %%
df = pd.concat([df2, data,df3], axis=1)

# %%
df
# Out:
#                                      accountId      health  isInBlueZone  \
# 0     account.226eb740251a4cc29c599c80f50338da  100.000000         False
# 1     account.152c19dec2cf4f9284d1ca80e11979cc  100.000000         False
# 2     account.eeb2cf1b27864e1ba6d9dd228925a505  100.000000         False
# 3     account.c67c01f25e8b42c4b750c43d4df9f9bb  100.000000         False
# 4     account.f20a9c53a9ef4f668e43ad1a26e368b6  100.000000         False
# 5     account.086cda2e657347099b5d6f4be03f4be4  100.000000         False
# 6     account.0c2c759549a54d3abb1eb79a95373fc5  100.000000         False
# 7     account.6ecad6ad6baa430380737c5945073b7b  100.000000         False
# 8     account.fb264769b99942dc98a9bdf6a0e11a5f  100.000000         False
# 9     account.d1e608afeaa942c593206ed1c1ff9340  100.000000         False
# 10    account.6057004907c2449690229f0c6feba056  100.000000         False
# 11    account.989d71e5c7254e4491193599e69bf896  100.000000         False
# ...

# %%
def print_match_stats(match_stat):
  match_id = match_stat['data']['dc091607-685f-49f4-8f95-eb29f353d580']
  match_attributes = match_stat['data']['attributes']
  print("match_id: dc091607-685f-49f4-8f95-eb29f353d580")
  print(json.dumps(match_attributes, sort_keys=False, indent=4))
  return
