# %% [markdown]
# <h3>In this file we transform data on player location and parachute landing to get the distances between players at different moments in time along the game.
# NOT FINISHED</h3>

# %%
import os
import sys
import json
import time
import datetime
from importlib import reload

import requests

import pandas as pd
import numpy as np

import external as ext

import pingouin as pg

# %% [markdown]
# ## Defining API calls info

# %%
# define api key
apikey = "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJqdGkiOiI4MjFjMGY4MC00NmFlLTAxMzgtYTkwMi0yNWIyZjA5NmRmYWMiLCJpc3MiOiJnYW1lbG9ja2VyIiwiaWF0IjoxNTg0MDMxNDAxLCJwdWIiOiJibHVlaG9sZSIsInRpdGxlIjoicHViZyIsImFwcCI6Im1pZ3VlbC1oZXJyYWV6In0.FvFkXnOYxXMtXeArAATb3f_BFrA3NgE9GBuTT6iL3fs"

# %%
# define request header
headers = {
    "Authorization": f'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJqdGkiOiI4MjFjMGY4MC00NmFlLTAxMzgtYTkwMi0yNWIyZjA5NmRmYWMiLCJpc3MiOiJnYW1lbG9ja2VyIiwiaWF0IjoxNTg0MDMxNDAxLCJwdWIiOiJibHVlaG9sZSIsInRpdGxlIjoicHViZyIsImFwcCI6Im1pZ3VlbC1oZXJyYWV6In0.FvFkXnOYxXMtXeArAATb3f_BFrA3NgE9GBuTT6iL3fs',
    "Accept": "application/vnd.api+json"
}

# %%
# Define the area
area = "pc-eu"

# %% [markdown]
# ## Getting match ids

# %% [markdown]
# <font size=5px>This part has been moved to the "extract_data.ipynb" notebook</font>

# %% [markdown]
# ## Getting match data (single match)

# %% [markdown]
# <p><font size=5px>This part has been moved to the "extract_data.ipynb" notebook</font></p>
# <p><font size=4px>What is now here is for the purpose of the analysis of the data of this single match</font></p>
# <p>From here onwards, we are using the data on match 4c76d82b-90f7-4fd1-9ceb-97b99347e94e, belonging to the pc shard</p>

# %%
# collect the match data of one match. We need this to get the assets id, needed to get the full telemetry data
url_collectassetsid = f"https://api.pubg.com/shards/pc/matches/4c76d82b-90f7-4fd1-9ceb-97b99347e94e"
response2 = requests.get(url_collectassetsid, headers=headers)

# %%
response2.json()
# Out:
# {'data': {'type': 'match',
#   'id': '4c76d82b-90f7-4fd1-9ceb-97b99347e94e',
#   'attributes': {'tags': None,
#    'mapName': 'Desert_Main',
#    'isCustomMatch': False,
#    'matchType': 'official',
#    'duration': 1780,
#    'stats': None,
#    'gameMode': 'squad',
#    'seasonState': 'progress',
#    'createdAt': '2020-04-08T22:34:53Z',
#    'titleId': 'bluehole-pubg',
#    'shardId': 'steam'},
#   'relationships': {'rosters': {'data': [{'type': 'roster',
#       'id': 'cb6eca6f-3082-4b72-9c17-96ee973e8b66'},
#      {'type': 'roster', 'id': 'aca7fc7c-dfb1-4c52-8a01-31ca043c3d61'},
#      {'type': 'roster', 'id': '9f96f524-cadd-4151-a952-1fbcabedbb75'},
#      {'type': 'roster', 'id': 'd2fe39c5-37e0-48c2-8549-044b5c678ea9'},
#      {'type': 'roster', 'id': '42742e82-fe7f-4573-ba2d-d4e443c40e36'},
#      {'type': 'roster', 'id': 'c4c310b2-d2d9-4f54-939d-57f906d43e41'},
#      {'type': 'roster', 'id': '2d2e2f1e-f46e-497d-bc11-8a5f8ec7e7f2'},
#      {'type': 'roster', 'id': '33b4d876-72b4-4cef-b4d7-494e10622184'},
#      {'type': 'roster', 'id': '23555790-0449-458c-8606-89957f6d73ae'},
#      {'type': 'roster', 'id': '75338cc7-b461-40bb-a593-28fa4bfd3d2e'},
#      {'type': 'roster', 'id': '77e8ac04-d031-4532-86a5-db912bdb9a8b'},
#      {'type': 'roster', 'id': '6d7d858a-e126-4dd1-9463-5d43ba2f7c1c'},
#      {'type': 'roster', 'id': 'd03c01a3-cf78-48c4-9087-b1ecde9342d1'},
#      {'type': 'roster', 'id': 'c3dd6e47-8d58-4578-b8b9-582ad8317d63'},
#      {'type': 'roster', 'id': '4399f539-4ad1-40f1-b8b0-8aea91d55e55'},
#      {'type': 'roster', 'id': '1fdfd817-1cdb-4bd9-8436-af5b9ec00a7d'},
#      {'type': 'roster', 'id': 'dc919749-e90f-431f-a02c-b5f0eff26421'},
#      {'type': 'roster', 'id': '99f19395-7cf9-40f2-a4c8-b1c238666fb4'},
#      {'type': 'roster', 'id': 'c1a9d04c-8b09-4c1c-ab20-8969128a9138'},
#      {'type': 'roster', 'id': 'c940d9d3-d433-4816-8457-894ea96a6946'},
#      {'type': 'roster', 'id': 'b95b45eb-7d94-4e5f-8fe7-a27f40dcd08b'}]},
#    'assets': {'data': [{'type': 'asset',
#       'id': '93e8aa34-79ed-11ea-bb70-aa92651f1055'}]}},
#   'links': {'self': 'https://api.playbattlegrounds.com/shards/steam/matches/4c76d82b-90f7-4fd1-9ceb-97b99347e94e',
#    'schema': ''}},
#  'included': [{'type': 'participant',
#    'id': 'ae48109c-b5e8-450d-b03a-e44f19b0c492',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 1,
#      'damageDealt': 19.35,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 39,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'kfox7197',
#      'playerId': 'account.6edabfe353ef4a12835f740fcf198c76',
#      'revives': 0,
#      'rideDistance': 0,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 791.488,
#      'vehicleDestroys': 0,
#      'walkDistance': 710.83563,
#      'weaponsAcquired': 4,
#      'winPlace': 10},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '504f3312-fde4-4c53-879f-d9463b2502af',
#    'attributes': {'shardId': 'steam',
#     'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 2,
#      'damageDealt': 23.109653,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 4,
#      'killPlace': 50,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'INOV77',
#      'playerId': 'account.ffad5b1280314f6dab6a48d6cf8cdf54',
#      'revives': 0,
#      'rideDistance': 3907.173,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 904.941,
#      'vehicleDestroys': 0,
#      'walkDistance': 982.56445,
#      'weaponsAcquired': 7,
#      'winPlace': 14},
#     'actor': ''}},
#   {'type': 'participant',
#    'id': 'fb18ca7f-1fda-48a2-8260-2d020e786a39',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 0,
#      'damageDealt': 0,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 40,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'Dancingly',
#      'playerId': 'account.c4f12abe7d2143bdbb3d4a9ea4ccd31e',
#      'revives': 0,
#      'rideDistance': 3386.1052,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1370.391,
#      'vehicleDestroys': 0,
#      'walkDistance': 2649.4485,
#      'weaponsAcquired': 8,
#      'winPlace': 11},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '531a6938-d304-4ea8-8896-56c7aed31177',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 6,
#      'damageDealt': 27.060001,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 36,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'LOCKLOAD007',
#      'playerId': 'account.749c1f3bc22841ccb17fd9aa3e65bccf',
#      'revives': 0,
#      'rideDistance': 2553.447,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1464.581,
#      'vehicleDestroys': 0,
#      'walkDistance': 2728.7402,
#      'weaponsAcquired': 5,
#      'winPlace': 7},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'roster',
#    'id': 'c940d9d3-d433-4816-8457-894ea96a6946',
#    'attributes': {'shardId': 'steam',
#     'stats': {'rank': 2, 'teamId': 22},
#     'won': 'false'},
#    'relationships': {'team': {'data': None},
#     'participants': {'data': [{'type': 'participant',
#        'id': '1b0242f7-ef66-4290-aebc-70ee2da26fe6'},
#       {'type': 'participant', 'id': 'e993828a-fdb8-4740-b26a-6fa6800a832f'},
#       {'type': 'participant', 'id': '8aa419eb-b530-4b04-9e98-c1db1a8c79b5'},
#       {'type': 'participant',
#        'id': 'e4916010-8c42-48b3-8b11-14bd5891a25d'}]}}},
#   {'type': 'participant',
#    'id': 'd90b0afb-b97a-4b92-8e0a-6df754df6407',
#    'attributes': {'stats': {'DBNOs': 1,
#      'assists': 0,
#      'boosts': 6,
#      'damageDealt': 176.00793,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 2,
#      'killPlace': 32,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'AKA447',
#      'playerId': 'account.4b3dcc0c663846c59981fb53f61eaf19',
#      'revives': 0,
#      'rideDistance': 5096.4043,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1700.392,
#      'vehicleDestroys': 0,
#      'walkDistance': 2276.3516,
#      'weaponsAcquired': 10,
#      'winPlace': 3},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': 'd17b538e-c7b1-4c76-a427-cf0022760a68',
#    'attributes': {'shardId': 'steam',
#     'stats': {'DBNOs': 2,
#      'assists': 0,
#      'boosts': 0,
#      'damageDealt': 157.17548,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 24,
#      'killStreaks': 1,
#      'kills': 1,
#      'longestKill': 22.69112,
#      'name': 'MiracleMan74',
#      'playerId': 'account.0d8958712dab4d8da4ac5183f2c2385a',
#      'revives': 0,
#      'rideDistance': 0,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 771.448,
#      'vehicleDestroys': 0,
#      'walkDistance': 282.0149,
#      'weaponsAcquired': 3,
#      'winPlace': 15},
#     'actor': ''}},
#   {'type': 'participant',
#    'id': '944c3bae-87f5-405a-a12a-e112205a8c74',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 0,
#      'damageDealt': 0,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 69,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'heysasa',
#      'playerId': 'account.e4464ed974c441bbaf5d75342810bcad',
#      'revives': 0,
#      'rideDistance': 0,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 300.438,
#      'vehicleDestroys': 0,
#      'walkDistance': 251.54076,
#      'weaponsAcquired': 3,
#      'winPlace': 19},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '20f910bc-ad83-40dc-89c2-ad7f7050f219',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 0,
#      'damageDealt': 0,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 63,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'Faxe99',
#      'playerId': 'account.eedb2af394cf40c2bc5809264a43df99',
#      'revives': 0,
#      'rideDistance': 0,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 502.703,
#      'vehicleDestroys': 0,
#      'walkDistance': 1708.4655,
#      'weaponsAcquired': 4,
#      'winPlace': 17},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '90280503-2d1f-4ee1-8088-ce46c17d2eb3',
#    'attributes': {'stats': {'DBNOs': 5,
#      'assists': 2,
#      'boosts': 5,
#      'damageDealt': 477.8381,
#      'deathType': 'byplayer',
#      'headshotKills': 1,
#      'heals': 12,
#      'killPlace': 7,
#      'killStreaks': 2,
#      'kills': 5,
#      'longestKill': 13.039005,
#      'name': 'DeathSs_LiuDeHua',
#      'playerId': 'account.93785a3f37e041ed8fe9221f9e8b9ca5',
#      'revives': 0,
#      'rideDistance': 2233.2607,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 995.736,
#      'vehicleDestroys': 0,
#      'walkDistance': 911.8027,
#      'weaponsAcquired': 9,
#      'winPlace': 13},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '1db77b04-865b-4eaa-85d5-440e4b0785f3',
#    'attributes': {'stats': {'DBNOs': 1,
#      'assists': 0,
#      'boosts': 0,
#      'damageDealt': 89.2,
#      'deathType': 'byplayer',
#      'headshotKills': 1,
#      'heals': 0,
#      'killPlace': 28,
#      'killStreaks': 1,
#      'kills': 1,
#      'longestKill': 3.975676,
#      'name': 'dxnub',
#      'playerId': 'account.f41a6e2001664439b818784d15ffc124',
#      'revives': 0,
#      'rideDistance': 0,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 124.03,
#      'vehicleDestroys': 0,
#      'walkDistance': 32.79204,
#      'weaponsAcquired': 2,
#      'winPlace': 20},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '5d0b0b6c-c52a-467b-8eb3-fb7c9253a993',
#    'attributes': {'shardId': 'steam',
#     'stats': {'DBNOs': 1,
#      'assists': 0,
#      'boosts': 2,
#      'damageDealt': 93.73803,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 41,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'Fudorin',
#      'playerId': 'account.6122a9daf65d448b930772a88651b53c',
#      'revives': 0,
#      'rideDistance': 2485.814,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1370.384,
#      'vehicleDestroys': 0,
#      'walkDistance': 2512.8796,
#      'weaponsAcquired': 5,
#      'winPlace': 11},
#     'actor': ''}},
#   {'type': 'participant',
#    'id': 'f8191e11-9b63-4d1b-bf31-0f0a77758892',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 1,
#      'damageDealt': 21.073034,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 45,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'Lavinn-',
#      'playerId': 'account.1f660c04029a489d92822e0282be22a0',
#      'revives': 0,
#      'rideDistance': 0,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1098.802,
#      'vehicleDestroys': 0,
#      'walkDistance': 1988.9312,
#      'weaponsAcquired': 3,
#      'winPlace': 12},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'roster',
#    'id': 'aca7fc7c-dfb1-4c52-8a01-31ca043c3d61',
#    'attributes': {'stats': {'rank': 1, 'teamId': 6},
#     'won': 'true',
#     'shardId': 'steam'},
#    'relationships': {'team': {'data': None},
#     'participants': {'data': [{'type': 'participant',
#        'id': 'a0e8ab82-9821-4887-a93f-0be0a336c599'},
#       {'type': 'participant', 'id': '9cf2bed2-32d8-4bec-a706-e136bd326f29'},
#       {'type': 'participant', 'id': '62616d87-0e1b-4364-aeb6-1480d2838c7f'},
#       {'type': 'participant',
#        'id': '0bb905eb-3466-492c-8ead-a9b52a33f7b6'}]}}},
#   {'type': 'participant',
#    'id': '9cf2bed2-32d8-4bec-a706-e136bd326f29',
#    'attributes': {'stats': {'DBNOs': 5,
#      'assists': 0,
#      'boosts': 8,
#      'damageDealt': 670.353,
#      'deathType': 'alive',
#      'headshotKills': 4,
#      'heals': 3,
#      'killPlace': 5,
#      'killStreaks': 2,
#      'kills': 5,
#      'longestKill': 168.04205,
#      'name': 'YEzi_YearSzy',
#      'playerId': 'account.9f0da77bfcab40149791be996d9e2e59',
#      'revives': 0,
#      'rideDistance': 1193.8525,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1780.006,
#      'vehicleDestroys': 0,
#      'walkDistance': 4164.0967,
#      'weaponsAcquired': 8,
#      'winPlace': 1},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '35a6f0fd-cef7-4c9e-89cd-fd7bea1c8629',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 3,
#      'boosts': 5,
#      'damageDealt': 120.7781,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 9,
#      'killPlace': 20,
#      'killStreaks': 1,
#      'kills': 1,
#      'longestKill': 191.06621,
#      'name': 'VX15872277853',
#      'playerId': 'account.542278ff8be14ac08a1b3de2877b4a7c',
#      'revives': 0,
#      'rideDistance': 2292.4563,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1514.608,
#      'vehicleDestroys': 1,
#      'walkDistance': 3296.8372,
#      'weaponsAcquired': 8,
#      'winPlace': 8},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'asset',
#    'id': '93e8aa34-79ed-11ea-bb70-aa92651f1055',
#    'attributes': {'name': 'telemetry',
#     'description': '',
#     'createdAt': '2020-04-08T23:06:28Z',
#     'URL': 'https://telemetry-cdn.playbattlegrounds.com/bluehole-pubg/steam/2020/04/08/23/06/93e8aa34-79ed-11ea-bb70-aa92651f1055-telemetry.json'}},
#   {'type': 'participant',
#    'id': 'dbd1b967-b63b-42f2-b92f-6e6dad8124f1',
#    'attributes': {'actor': '',
#     'shardId': 'steam',
#     'stats': {'DBNOs': 1,
#      'assists': 0,
#      'boosts': 3,
#      'damageDealt': 196.3725,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 3,
#      'killPlace': 10,
#      'killStreaks': 2,
#      'kills': 3,
#      'longestKill': 9.218088,
#      'name': 'OMGNOWAYTHATSBS',
#      'playerId': 'account.54a138a899ea43919a51de65323d9287',
#      'revives': 0,
#      'rideDistance': 3039.804,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1592.233,
#      'vehicleDestroys': 0,
#      'walkDistance': 2623.0034,
#      'weaponsAcquired': 3,
#      'winPlace': 7}}},
#   {'type': 'participant',
#    'id': 'e47463b2-4b88-477a-8ad2-79931296e68b',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 0,
#      'damageDealt': 0,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 37,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'Bubbabear85',
#      'playerId': 'account.50adcc0db4de465aa9ae3b726498f5c7',
#      'revives': 0,
#      'rideDistance': 2731.7412,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1462.842,
#      'vehicleDestroys': 0,
#      'walkDistance': 2409.3298,
#      'weaponsAcquired': 5,
#      'winPlace': 7},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '659b5b2b-710b-4b01-804a-e13b504d3aa6',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 0,
#      'damageDealt': 22.140001,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 67,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'BLAVKMUSIKPCXB',
#      'playerId': 'account.c3baffb7b59f424cb8e0234e8a3d5542',
#      'revives': 0,
#      'rideDistance': 0,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 368.105,
#      'vehicleDestroys': 0,
#      'walkDistance': 447.4277,
#      'weaponsAcquired': 1,
#      'winPlace': 18},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '534deaae-cad6-4b92-91c6-1adfe5b5d1b1',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 1,
#      'damageDealt': 44.76985,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 1,
#      'killPlace': 44,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'KillerDong7',
#      'playerId': 'account.0261932f6e834d23a1e5af9641e81a07',
#      'revives': 0,
#      'rideDistance': 2145.3115,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1207.728,
#      'vehicleDestroys': 0,
#      'walkDistance': 1599.535,
#      'weaponsAcquired': 4,
#      'winPlace': 12},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': 'd3af889c-96b9-4fb5-854b-67d14cb32a3b',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 2,
#      'damageDealt': 75.78497,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 5,
#      'killPlace': 43,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'GGHumannn',
#      'playerId': 'account.1c38aec23e5e4a458a210a6d16c8eca5',
#      'revives': 1,
#      'rideDistance': 2244.041,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1208.164,
#      'vehicleDestroys': 0,
#      'walkDistance': 1616.9617,
#      'weaponsAcquired': 8,
#      'winPlace': 12},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': 'ce9c3944-09f7-48a6-abd1-b17d745dcbec',
#    'attributes': {'stats': {'DBNOs': 2,
#      'assists': 1,
#      'boosts': 6,
#      'damageDealt': 333.09555,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 1,
#      'killPlace': 13,
#      'killStreaks': 2,
#      'kills': 2,
#      'longestKill': 19.799921,
#      'name': '7ooc_-_',
#      'playerId': 'account.79c2f8876c4840a3a8de76d5be3ddf71',
#      'revives': 0,
#      'rideDistance': 3671.6963,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1453.736,
#      'vehicleDestroys': 0,
#      'walkDistance': 3408.8591,
#      'weaponsAcquired': 5,
#      'winPlace': 8},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '2ef2f93e-8179-4cdd-baa4-90fc0954d133',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 1,
#      'damageDealt': 0,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 68,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'Landpuss',
#      'playerId': 'account.b2875d9ab5484d1aa41cbf9ba8e8ae2e',
#      'revives': 0,
#      'rideDistance': 0,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 317.974,
#      'vehicleDestroys': 0,
#      'walkDistance': 669.96857,
#      'weaponsAcquired': 2,
#      'winPlace': 18},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '12c48e3f-ff62-42d6-a021-74f91e3e6692',
#    'attributes': {'actor': '',
#     'shardId': 'steam',
#     'stats': {'DBNOs': 1,
#      'assists': 0,
#      'boosts': 4,
#      'damageDealt': 156.51,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 5,
#      'killPlace': 22,
#      'killStreaks': 1,
#      'kills': 1,
#      'longestKill': 81.64188,
#      'name': 'riteintheas',
#      'playerId': 'account.1d52dff3cfbf4e5b95020a71f84f0c63',
#      'revives': 0,
#      'rideDistance': 646.322,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1136.251,
#      'vehicleDestroys': 0,
#      'walkDistance': 1106.0255,
#      'weaponsAcquired': 11,
#      'winPlace': 12}}},
#   {'type': 'roster',
#    'id': '2d2e2f1e-f46e-497d-bc11-8a5f8ec7e7f2',
#    'attributes': {'stats': {'rank': 4, 'teamId': 13},
#     'won': 'false',
#     'shardId': 'steam'},
#    'relationships': {'team': {'data': None},
#     'participants': {'data': [{'type': 'participant',
#        'id': '06411b82-23e3-48cb-bf25-9eff91fac3c3'},
#       {'type': 'participant', 'id': 'db62c079-b369-4838-887b-f14a636ec0d0'},
#       {'type': 'participant', 'id': '534deaae-cad6-4b92-91c6-1adfe5b5d1b1'},
#       {'type': 'participant',
#        'id': 'd3af889c-96b9-4fb5-854b-67d14cb32a3b'}]}}},
#   {'type': 'roster',
#    'id': 'c3dd6e47-8d58-4578-b8b9-582ad8317d63',
#    'attributes': {'stats': {'rank': 9, 'teamId': 17},
#     'won': 'false',
#     'shardId': 'steam'},
#    'relationships': {'team': {'data': None},
#     'participants': {'data': [{'type': 'participant',
#        'id': '12c48e3f-ff62-42d6-a021-74f91e3e6692'},
#       {'type': 'participant', 'id': '44adeb7d-7c96-4c7f-8ee8-c50cc544b10e'},
#       {'type': 'participant', 'id': 'f8191e11-9b63-4d1b-bf31-0f0a77758892'},
#       {'type': 'participant',
#        'id': 'b6589b41-bb6d-4bf1-aec3-64b487be28d0'}]}}},
#   {'type': 'participant',
#    'id': '10f2a666-1a63-4aac-9f18-471e7a37d2e0',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 0,
#      'damageDealt': 0,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 76,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'BIU-DDDSJ',
#      'playerId': 'account.e60bd0f0cc8040b6a5c0a49d5ad1cdc3',
#      'revives': 0,
#      'rideDistance': 0,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 105.854,
#      'vehicleDestroys': 0,
#      'walkDistance': 10.192129,
#      'weaponsAcquired': 0,
#      'winPlace': 21},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'roster',
#    'id': 'd03c01a3-cf78-48c4-9087-b1ecde9342d1',
#    'attributes': {'stats': {'rank': 11, 'teamId': 25},
#     'won': 'false',
#     'shardId': 'steam'},
#    'relationships': {'participants': {'data': [{'type': 'participant',
#        'id': '8e5c44ec-a4a2-48e8-b198-4a233ccc564f'},
#       {'type': 'participant', 'id': '5d0b0b6c-c52a-467b-8eb3-fb7c9253a993'},
#       {'type': 'participant', 'id': 'fb18ca7f-1fda-48a2-8260-2d020e786a39'}]},
#     'team': {'data': None}}},
#   {'type': 'participant',
#    'id': '62616d87-0e1b-4364-aeb6-1480d2838c7f',
#    'attributes': {'stats': {'DBNOs': 6,
#      'assists': 1,
#      'boosts': 6,
#      'damageDealt': 671.23346,
#      'deathType': 'byplayer',
#      'headshotKills': 2,
#      'heals': 0,
#      'killPlace': 2,
#      'killStreaks': 1,
#      'kills': 6,
#      'longestKill': 27.218365,
#      'name': 'SLyx7cIOs',
#      'playerId': 'account.e4d70b1f31ce451fa55e46eb95278715',
#      'revives': 1,
#      'rideDistance': 2399.0454,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1494.53,
#      'vehicleDestroys': 0,
#      'walkDistance': 3834.8965,
#      'weaponsAcquired': 4,
#      'winPlace': 1},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': 'cf722fe5-9f4e-4619-98ed-2c2e9dc5e785',
#    'attributes': {'actor': '',
#     'shardId': 'steam',
#     'stats': {'DBNOs': 5,
#      'assists': 1,
#      'boosts': 6,
#      'damageDealt': 704.7568,
#      'deathType': 'byplayer',
#      'headshotKills': 2,
#      'heals': 1,
#      'killPlace': 4,
#      'killStreaks': 2,
#      'kills': 6,
#      'longestKill': 78.83598,
#      'name': 'ChiWoDaDiao-',
#      'playerId': 'account.c2200a42a77349e582788e9a6081aeb4',
#      'revives': 2,
#      'rideDistance': 2260.656,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 995.747,
#      'vehicleDestroys': 0,
#      'walkDistance': 939.82666,
#      'weaponsAcquired': 7,
#      'winPlace': 13}}},
#   {'type': 'participant',
#    'id': '0a474e26-793f-4df6-b759-de4aefb6ad70',
#    'attributes': {'shardId': 'steam',
#     'stats': {'DBNOs': 4,
#      'assists': 0,
#      'boosts': 8,
#      'damageDealt': 462.77106,
#      'deathType': 'byplayer',
#      'headshotKills': 1,
#      'heals': 4,
#      'killPlace': 9,
#      'killStreaks': 1,
#      'kills': 3,
#      'longestKill': 110.36585,
#      'name': '8344',
#      'playerId': 'account.ff1ec4f49b224de8a8107bc73fae0081',
#      'revives': 0,
#      'rideDistance': 7475.658,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1467.021,
#      'vehicleDestroys': 1,
#      'walkDistance': 2202.7275,
#      'weaponsAcquired': 9,
#      'winPlace': 5},
#     'actor': ''}},
#   {'type': 'participant',
#    'id': 'b4955f69-1abf-4d39-86a8-6649119000fb',
#    'attributes': {'stats': {'DBNOs': 1,
#      'assists': 0,
#      'boosts': 1,
#      'damageDealt': 195.57616,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 3,
#      'killPlace': 26,
#      'killStreaks': 1,
#      'kills': 1,
#      'longestKill': 7.518613,
#      'name': 'L4_Desweet',
#      'playerId': 'account.4b0e221bb7b441218123956666fcc5c5',
#      'revives': 0,
#      'rideDistance': 0,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 312.703,
#      'vehicleDestroys': 0,
#      'walkDistance': 245.00934,
#      'weaponsAcquired': 2,
#      'winPlace': 19},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '06ca4ada-302e-4783-b1c1-6e6fe47f4743',
#    'attributes': {'stats': {'DBNOs': 1,
#      'assists': 0,
#      'boosts': 0,
#      'damageDealt': 185.075,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 64,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'FriedeggMan',
#      'playerId': 'account.39ce2adafa4340fca6a983d59ed8a307',
#      'revives': 0,
#      'rideDistance': 0,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 486.293,
#      'vehicleDestroys': 0,
#      'walkDistance': 1086.7596,
#      'weaponsAcquired': 3,
#      'winPlace': 17},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '5feb78dc-30af-4a11-8880-5a359dcdbab9',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 0,
#      'damageDealt': 0,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 73,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'Mac_1205',
#      'playerId': 'account.aae7ef8724284447953034a9ccbe89aa',
#      'revives': 0,
#      'rideDistance': 0,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 155.381,
#      'vehicleDestroys': 0,
#      'walkDistance': 101.8409,
#      'weaponsAcquired': 1,
#      'winPlace': 20},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'roster',
#    'id': '99f19395-7cf9-40f2-a4c8-b1c238666fb4',
#    'attributes': {'stats': {'rank': 15, 'teamId': 19},
#     'won': 'false',
#     'shardId': 'steam'},
#    'relationships': {'team': {'data': None},
#     'participants': {'data': [{'type': 'participant',
#        'id': 'b5925d25-1d58-4e04-92f3-ddebb4d47fe7'},
#       {'type': 'participant', 'id': 'b8831bc5-0797-44d2-bb7b-34318f1b1775'},
#       {'type': 'participant', 'id': 'd17b538e-c7b1-4c76-a427-cf0022760a68'},
#       {'type': 'participant',
#        'id': 'ff0e1adc-07ac-4a06-b138-a9dc1ac4f93a'}]}}},
#   {'type': 'participant',
#    'id': 'c14d66d2-187d-470c-904b-33c81a0909b1',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 0,
#      'damageDealt': 0,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 55,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'chewy7318',
#      'playerId': 'account.385a9f5436af46cf968ffff7219bc696',
#      'revives': 0,
#      'rideDistance': 9321.475,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 781.899,
#      'vehicleDestroys': 0,
#      'walkDistance': 583.5012,
#      'weaponsAcquired': 5,
#      'winPlace': 16},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '98b24b13-f541-49c8-ad37-6cb850e9d802',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 8,
#      'damageDealt': 174.63391,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 1,
#      'killPlace': 31,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'molahhh',
#      'playerId': 'account.e6798bd0974349519ff0437fffc4e25f',
#      'revives': 0,
#      'rideDistance': 5532.1094,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1702.59,
#      'vehicleDestroys': 0,
#      'walkDistance': 2511.4558,
#      'weaponsAcquired': 7,
#      'winPlace': 3},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': 'b5925d25-1d58-4e04-92f3-ddebb4d47fe7',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 1,
#      'damageDealt': 21.028847,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 7,
#      'killPlace': 52,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'CALLAHYM',
#      'playerId': 'account.5adf56e2126c495ebbe51050b77fba5d',
#      'revives': 0,
#      'rideDistance': 0,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 832.45,
#      'vehicleDestroys': 0,
#      'walkDistance': 665.8926,
#      'weaponsAcquired': 3,
#      'winPlace': 15},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': 'b8831bc5-0797-44d2-bb7b-34318f1b1775',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 2,
#      'damageDealt': 94.15006,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 1,
#      'killPlace': 51,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'Badbart314',
#      'playerId': 'account.3354b9d270014aa2828dd4f5a12b2776',
#      'revives': 1,
#      'rideDistance': 0,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 832.458,
#      'vehicleDestroys': 0,
#      'walkDistance': 880.2703,
#      'weaponsAcquired': 5,
#      'winPlace': 15},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'roster',
#    'id': '75338cc7-b461-40bb-a593-28fa4bfd3d2e',
#    'attributes': {'won': 'false',
#     'shardId': 'steam',
#     'stats': {'rank': 8, 'teamId': 14}},
#    'relationships': {'team': {'data': None},
#     'participants': {'data': [{'type': 'participant',
#        'id': 'f432baa0-9cf2-4bb1-ba76-ab88572e5cf1'},
#       {'type': 'participant', 'id': '35a6f0fd-cef7-4c9e-89cd-fd7bea1c8629'},
#       {'type': 'participant',
#        'id': 'ce9c3944-09f7-48a6-abd1-b17d745dcbec'}]}}},
#   {'type': 'participant',
#    'id': '391d32ab-a5e9-4183-9f2e-9edeb693dd8e',
#    'attributes': {'stats': {'DBNOs': 1,
#      'assists': 0,
#      'boosts': 0,
#      'damageDealt': 100,
#      'deathType': 'byplayer',
#      'headshotKills': 1,
#      'heals': 0,
#      'killPlace': 27,
#      'killStreaks': 1,
#      'kills': 1,
#      'longestKill': 11.607942,
#      'name': 'AhYeahAhYeah',
#      'playerId': 'account.38fab72c58f74955b1cc6b780b1c7417',
#      'revives': 0,
#      'rideDistance': 0,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 312.694,
#      'vehicleDestroys': 0,
#      'walkDistance': 378.34317,
#      'weaponsAcquired': 5,
#      'winPlace': 19},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '57caeb81-4b13-47cd-a7f8-098dbb64c671',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 0,
#      'damageDealt': 54.120003,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 74,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'Dyrand',
#      'playerId': 'account.c83a131297394d01a64a9a080e03372e',
#      'revives': 0,
#      'rideDistance': 0,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 153.458,
#      'vehicleDestroys': 0,
#      'walkDistance': 76.73045,
#      'weaponsAcquired': 2,
#      'winPlace': 20},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '546cd675-5dd2-4544-a87b-2f0cd3292554',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 0,
#      'damageDealt': 0,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 65,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'Jubly',
#      'playerId': 'account.b0f435dcdede464e9beca298f4e6b90c',
#      'revives': 0,
#      'rideDistance': 1331.3315,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 464.328,
#      'vehicleDestroys': 0,
#      'walkDistance': 969.36475,
#      'weaponsAcquired': 2,
#      'winPlace': 18},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': 'c9329972-106e-43e4-99aa-4e4f955528b8',
#    'attributes': {'stats': {'DBNOs': 1,
#      'assists': 1,
#      'boosts': 4,
#      'damageDealt': 142.24554,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 3,
#      'killPlace': 33,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': '8255',
#      'playerId': 'account.f3c3476295344033b5f098651acc73e7',
#      'revives': 0,
#      'rideDistance': 7533.5996,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1641.256,
#      'vehicleDestroys': 0,
#      'walkDistance': 2428.7007,
#      'weaponsAcquired': 4,
#      'winPlace': 5},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'roster',
#    'id': '4399f539-4ad1-40f1-b8b0-8aea91d55e55',
#    'attributes': {'stats': {'rank': 3, 'teamId': 9},
#     'won': 'false',
#     'shardId': 'steam'},
#    'relationships': {'participants': {'data': [{'type': 'participant',
#        'id': '98b24b13-f541-49c8-ad37-6cb850e9d802'},
#       {'type': 'participant', 'id': '052bbe4b-78a0-4ec5-94db-4582f7d6d073'},
#       {'type': 'participant', 'id': 'd90b0afb-b97a-4b92-8e0a-6df754df6407'}]},
#     'team': {'data': None}}},
#   {'type': 'roster',
#    'id': 'c1a9d04c-8b09-4c1c-ab20-8969128a9138',
#    'attributes': {'stats': {'rank': 17, 'teamId': 27},
#     'won': 'false',
#     'shardId': 'steam'},
#    'relationships': {'team': {'data': None},
#     'participants': {'data': [{'type': 'participant',
#        'id': '98b84ee2-fa43-4b36-8e61-5434b7088176'},
#       {'type': 'participant', 'id': '6119bb93-4711-4d08-8593-67d0d05e4ecd'},
#       {'type': 'participant', 'id': 'a3012dc8-09f0-46f1-a1d7-75f6201d1dee'},
#       {'type': 'participant',
#        'id': '42891f57-26da-46fa-b7b5-4a761363fa83'}]}}},
#   {'type': 'roster',
#    'id': '23555790-0449-458c-8606-89957f6d73ae',
#    'attributes': {'stats': {'rank': 20, 'teamId': 1},
#     'won': 'false',
#     'shardId': 'steam'},
#    'relationships': {'team': {'data': None},
#     'participants': {'data': [{'type': 'participant',
#        'id': '48955b52-7d54-4248-86bc-435a765cb5a0'},
#       {'type': 'participant', 'id': '5feb78dc-30af-4a11-8880-5a359dcdbab9'},
#       {'type': 'participant', 'id': '1db77b04-865b-4eaa-85d5-440e4b0785f3'},
#       {'type': 'participant',
#        'id': '66f8ae43-fa8d-46fc-a754-0bed64edea12'}]}}},
#   {'type': 'participant',
#    'id': '7ef8d730-f6a7-4c24-8db8-fcf956f00c01',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 1,
#      'damageDealt': 26.999117,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 54,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'Noir_Fox',
#      'playerId': 'account.4c781ea0678c46ce8b27dc6c66d543b6',
#      'revives': 0,
#      'rideDistance': 5821.6714,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 787.448,
#      'vehicleDestroys': 0,
#      'walkDistance': 893.95264,
#      'weaponsAcquired': 3,
#      'winPlace': 16},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': 'a19e9493-3386-4edc-b295-ab33370b8858',
#    'attributes': {'stats': {'DBNOs': 2,
#      'assists': 2,
#      'boosts': 6,
#      'damageDealt': 327.57547,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 13,
#      'killPlace': 21,
#      'killStreaks': 1,
#      'kills': 1,
#      'longestKill': 31.067595,
#      'name': 'Bob_Roberts',
#      'playerId': 'account.aaccc75f95d5416ebf19960691dc13c6',
#      'revives': 0,
#      'rideDistance': 5628.611,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1486.054,
#      'vehicleDestroys': 1,
#      'walkDistance': 1607.6,
#      'weaponsAcquired': 9,
#      'winPlace': 10},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '33ad450f-b316-4639-bdde-e592ca02a295',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 0,
#      'damageDealt': 0,
#      'deathType': 'byzone',
#      'headshotKills': 0,
#      'heals': 1,
#      'killPlace': 35,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'HITECHPLUMBER69',
#      'playerId': 'account.08c1815b804c4b1494002f149c6d6601',
#      'revives': 1,
#      'rideDistance': 1207.2373,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1491.132,
#      'vehicleDestroys': 0,
#      'walkDistance': 2390.669,
#      'weaponsAcquired': 7,
#      'winPlace': 6},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '5de316f7-1ccd-4559-bb67-20e0e35206c4',
#    'attributes': {'stats': {'DBNOs': 3,
#      'assists': 3,
#      'boosts': 8,
#      'damageDealt': 494.4364,
#      'deathType': 'byplayer',
#      'headshotKills': 2,
#      'heals': 5,
#      'killPlace': 6,
#      'killStreaks': 2,
#      'kills': 5,
#      'longestKill': 706.2315,
#      'name': 'G7_WenG',
#      'playerId': 'account.0b4c6fd0d4d84cb69ad625fc35c87721',
#      'revives': 0,
#      'rideDistance': 7571.0312,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1641.244,
#      'vehicleDestroys': 1,
#      'walkDistance': 2831.7073,
#      'weaponsAcquired': 3,
#      'winPlace': 5},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '8aa419eb-b530-4b04-9e98-c1db1a8c79b5',
#    'attributes': {'stats': {'DBNOs': 1,
#      'assists': 0,
#      'boosts': 9,
#      'damageDealt': 360.5515,
#      'deathType': 'byplayer',
#      'headshotKills': 1,
#      'heals': 1,
#      'killPlace': 11,
#      'killStreaks': 2,
#      'kills': 2,
#      'longestKill': 126.07245,
#      'name': 'Elessare',
#      'playerId': 'account.1750c61aa81441f6a9dcf81ed98196b6',
#      'revives': 1,
#      'rideDistance': 4256.8457,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1771.832,
#      'vehicleDestroys': 0,
#      'walkDistance': 2783.4006,
#      'weaponsAcquired': 8,
#      'winPlace': 2},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'roster',
#    'id': '42742e82-fe7f-4573-ba2d-d4e443c40e36',
#    'attributes': {'stats': {'rank': 14, 'teamId': 23},
#     'won': 'false',
#     'shardId': 'steam'},
#    'relationships': {'team': {'data': None},
#     'participants': {'data': [{'type': 'participant',
#        'id': '659b5b2b-710b-4b01-804a-e13b504d3aa6'},
#       {'type': 'participant', 'id': '20f910bc-ad83-40dc-89c2-ad7f7050f219'},
#       {'type': 'participant', 'id': '8f9fbcea-1efb-4675-b29d-b8d8fb403597'},
#       {'type': 'participant',
#        'id': '504f3312-fde4-4c53-879f-d9463b2502af'}]}}},
#   {'type': 'participant',
#    'id': '42891f57-26da-46fa-b7b5-4a761363fa83',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 0,
#      'damageDealt': 166.44382,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 5,
#      'killPlace': 62,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'Diesvtfocus',
#      'playerId': 'account.41435623c76a4bae90077cbce53601a3',
#      'revives': 0,
#      'rideDistance': 0,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 520.901,
#      'vehicleDestroys': 0,
#      'walkDistance': 223.28822,
#      'weaponsAcquired': 5,
#      'winPlace': 17},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '1b0242f7-ef66-4290-aebc-70ee2da26fe6',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 1,
#      'boosts': 2,
#      'damageDealt': 102.40895,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 30,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': '7Burial',
#      'playerId': 'account.3759e2262f4c492cbd989527b78345b5',
#      'revives': 0,
#      'rideDistance': 4360.7764,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1749.203,
#      'vehicleDestroys': 0,
#      'walkDistance': 2225.0693,
#      'weaponsAcquired': 4,
#      'winPlace': 2},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '0bb905eb-3466-492c-8ead-a9b52a33f7b6',
#    'attributes': {'shardId': 'steam',
#     'stats': {'DBNOs': 6,
#      'assists': 1,
#      'boosts': 7,
#      'damageDealt': 721.25696,
#      'deathType': 'alive',
#      'headshotKills': 0,
#      'heals': 10,
#      'killPlace': 1,
#      'killStreaks': 1,
#      'kills': 7,
#      'longestKill': 393.82614,
#      'name': 'Kev1nMo',
#      'playerId': 'account.6c124c8a6df840308d5ccd5324871b44',
#      'revives': 0,
#      'rideDistance': 376.93442,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1780.006,
#      'vehicleDestroys': 0,
#      'walkDistance': 4308.2686,
#      'weaponsAcquired': 6,
#      'winPlace': 1},
#     'actor': ''}},
#   {'type': 'participant',
#    'id': 'f6969f2d-fa67-4136-b899-50cbdb92959a',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 0,
#      'damageDealt': 57.799976,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 25,
#      'killStreaks': 1,
#      'kills': 1,
#      'longestKill': 11.833576,
#      'name': 'Cadenn',
#      'playerId': 'account.fa20a446eea64586b4033135908d921a',
#      'revives': 0,
#      'rideDistance': 0,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 312.709,
#      'vehicleDestroys': 0,
#      'walkDistance': 408.33017,
#      'weaponsAcquired': 4,
#      'winPlace': 19},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': 'f78eabb9-9fa1-4b14-873b-44511fcff2d8',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 1,
#      'damageDealt': 0,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 53,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'Solomon5968',
#      'playerId': 'account.d22cd0ef458c411caef12c9f5db9ea27',
#      'revives': 0,
#      'rideDistance': 0,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 798.544,
#      'vehicleDestroys': 0,
#      'walkDistance': 1096.521,
#      'weaponsAcquired': 6,
#      'winPlace': 15},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': 'f432baa0-9cf2-4bb1-ba76-ab88572e5cf1',
#    'attributes': {'stats': {'DBNOs': 2,
#      'assists': 1,
#      'boosts': 5,
#      'damageDealt': 191.62158,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 3,
#      'killPlace': 12,
#      'killStreaks': 2,
#      'kills': 2,
#      'longestKill': 80.527374,
#      'name': 'ReaPer_LiQAQ',
#      'playerId': 'account.79208548b044413bb761d34f19783a49',
#      'revives': 1,
#      'rideDistance': 3010.1882,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1463.279,
#      'vehicleDestroys': 0,
#      'walkDistance': 3459.624,
#      'weaponsAcquired': 5,
#      'winPlace': 8},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '44adeb7d-7c96-4c7f-8ee8-c50cc544b10e',
#    'attributes': {'shardId': 'steam',
#     'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 3,
#      'damageDealt': 57.553265,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 1,
#      'killPlace': 47,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'jtbullet',
#      'playerId': 'account.bdc00b85422c4807bdc3de91d56be5d6',
#      'revives': 0,
#      'rideDistance': 0,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1089.367,
#      'vehicleDestroys': 0,
#      'walkDistance': 1781.8202,
#      'weaponsAcquired': 4,
#      'winPlace': 12},
#     'actor': ''}},
#   {'type': 'participant',
#    'id': 'ff0e1adc-07ac-4a06-b138-a9dc1ac4f93a',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 0,
#      'damageDealt': 0,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 1,
#      'killPlace': 70,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'Ryjack22',
#      'playerId': 'account.62d34dd73cf54e41b2447d172c9609f3',
#      'revives': 0,
#      'rideDistance': 0,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 292.691,
#      'vehicleDestroys': 0,
#      'walkDistance': 172.55385,
#      'weaponsAcquired': 3,
#      'winPlace': 19},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'roster',
#    'id': 'd2fe39c5-37e0-48c2-8549-044b5c678ea9',
#    'attributes': {'stats': {'rank': 10, 'teamId': 21},
#     'won': 'false',
#     'shardId': 'steam'},
#    'relationships': {'team': {'data': None},
#     'participants': {'data': [{'type': 'participant',
#        'id': 'f78eabb9-9fa1-4b14-873b-44511fcff2d8'},
#       {'type': 'participant', 'id': 'a19e9493-3386-4edc-b295-ab33370b8858'},
#       {'type': 'participant', 'id': '82e9920f-6ebc-41de-aef5-84ccc0780421'},
#       {'type': 'participant',
#        'id': 'ae48109c-b5e8-450d-b03a-e44f19b0c492'}]}}},
#   {'type': 'roster',
#    'id': '1fdfd817-1cdb-4bd9-8436-af5b9ec00a7d',
#    'attributes': {'stats': {'rank': 21, 'teamId': 10},
#     'won': 'false',
#     'shardId': 'steam'},
#    'relationships': {'team': {'data': None},
#     'participants': {'data': [{'type': 'participant',
#        'id': '10f2a666-1a63-4aac-9f18-471e7a37d2e0'},
#       {'type': 'participant',
#        'id': 'd7bf78e8-07c5-483f-b752-2bd807868641'}]}}},
#   {'type': 'participant',
#    'id': '6119bb93-4711-4d08-8593-67d0d05e4ecd',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 0,
#      'damageDealt': 0,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 59,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'LDrai29',
#      'playerId': 'account.d9863a055ddd4cf8b192fc7a094692c3',
#      'revives': 0,
#      'rideDistance': 0,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 634.717,
#      'vehicleDestroys': 0,
#      'walkDistance': 409.84286,
#      'weaponsAcquired': 3,
#      'winPlace': 17},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'roster',
#    'id': '33b4d876-72b4-4cef-b4d7-494e10622184',
#    'attributes': {'shardId': 'steam',
#     'stats': {'rank': 12, 'teamId': 15},
#     'won': 'false'},
#    'relationships': {'team': {'data': None},
#     'participants': {'data': [{'type': 'participant',
#        'id': '11492cad-51f6-4502-9078-9a9c9d663097'},
#       {'type': 'participant', 'id': '73697a22-13e5-4de6-9398-9699e5c35ed7'},
#       {'type': 'participant',
#        'id': '06ca4ada-302e-4783-b1c1-6e6fe47f4743'}]}}},
#   {'type': 'participant',
#    'id': '06411b82-23e3-48cb-bf25-9eff91fac3c3',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 3,
#      'damageDealt': 26.599998,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 2,
#      'killPlace': 19,
#      'killStreaks': 1,
#      'kills': 1,
#      'longestKill': 17.66754,
#      'name': 'Thursty1991',
#      'playerId': 'account.a2fd712cae2241179afc28e05170e306',
#      'revives': 0,
#      'rideDistance': 9831.441,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1662.262,
#      'vehicleDestroys': 0,
#      'walkDistance': 1680.5696,
#      'weaponsAcquired': 6,
#      'winPlace': 4},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': 'db62c079-b369-4838-887b-f14a636ec0d0',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 1,
#      'boosts': 1,
#      'damageDealt': 114.14208,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 2,
#      'killPlace': 18,
#      'killStreaks': 1,
#      'kills': 1,
#      'longestKill': 5.920578,
#      'name': 'SneakyFokker',
#      'playerId': 'account.6161f979fe184888bb9b733cc18960c7',
#      'revives': 0,
#      'rideDistance': 15166.87,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1662.273,
# ...
#   {'type': 'participant',
#    'id': '689ef05e-b448-46e6-9d82-974f3b57ff47',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 0,
#      'damageDealt': 0,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 48,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'Youlaoban',
#      'playerId': 'account.c3d2339935824cdc9e55f9c7b575e355',
#      'revives': 0,
#      'rideDistance': 0,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 88.804,
#      'vehicleDestroys': 0,
#      'walkDistance': 0.1236683,
#      'weaponsAcquired': 0,
#      'winPlace': 13},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '8e5c44ec-a4a2-48e8-b198-4a233ccc564f',
#    'attributes': {'stats': {'DBNOs': 2,
#      'assists': 0,
#      'boosts': 3,
#      'damageDealt': 197.81337,
#      'deathType': 'byplayer',
#      'headshotKills': 1,
#      'heals': 0,
#      'killPlace': 15,
#      'killStreaks': 2,
#      'kills': 2,
#      'longestKill': 19.463108,
#      'name': 'Mondoja',
#      'playerId': 'account.430e7112176d4d849d2a873e19ec199e',
#      'revives': 0,
#      'rideDistance': 2993.3076,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1222.533,
#      'vehicleDestroys': 0,
#      'walkDistance': 1672.595,
#      'weaponsAcquired': 3,
#      'winPlace': 11},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': 'e993828a-fdb8-4740-b26a-6fa6800a832f',
#    'attributes': {'stats': {'DBNOs': 1,
#      'assists': 0,
#      'boosts': 2,
#      'damageDealt': 12,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 5,
#      'killPlace': 16,
#      'killStreaks': 1,
#      'kills': 1,
#      'longestKill': 252.44148,
#      'name': 'duoduobaby0613',
#      'playerId': 'account.dfdb53bf20534cffa29b7207076923d2',
#      'revives': 0,
#      'rideDistance': 4253.0786,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1771.842,
#      'vehicleDestroys': 0,
#      'walkDistance': 1833.0565,
#      'weaponsAcquired': 3,
#      'winPlace': 2},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '82e9920f-6ebc-41de-aef5-84ccc0780421',
#    'attributes': {'actor': '',
#     'shardId': 'steam',
#     'stats': {'DBNOs': 1,
#      'assists': 0,
#      'boosts': 0,
#      'damageDealt': 100,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 23,
#      'killStreaks': 1,
#      'kills': 1,
#      'longestKill': 27.091127,
#      'name': 'The_Bryonic_Man',
#      'playerId': 'account.e5be34fde69841ab9cf6b6681482d9d2',
#      'revives': 0,
#      'rideDistance': 0,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 778.583,
#      'vehicleDestroys': 0,
#      'walkDistance': 1084.0175,
#      'weaponsAcquired': 6,
#      'winPlace': 15}}},
#   {'type': 'participant',
#    'id': '7f51bd23-8d1c-44a0-8ef8-4fc40eee1de6',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 0,
#      'damageDealt': 0,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 66,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'DougDimmadab',
#      'playerId': 'account.c9c4480e5fa348dfa7d1a14a29ba87dc',
#      'revives': 0,
#      'rideDistance': 854.8995,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 464.321,
#      'vehicleDestroys': 0,
#      'walkDistance': 1061.2574,
#      'weaponsAcquired': 2,
#      'winPlace': 18},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': 'a3012dc8-09f0-46f1-a1d7-75f6201d1dee',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 1,
#      'damageDealt': 35.38629,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 58,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'HotDoggHands',
#      'playerId': 'account.1b9f91fb61504402b9774fcfa430e57e',
#      'revives': 0,
#      'rideDistance': 0,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 634.723,
#      'vehicleDestroys': 0,
#      'walkDistance': 424.95966,
#      'weaponsAcquired': 5,
#      'winPlace': 17},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': 'e4916010-8c42-48b3-8b11-14bd5891a25d',
#    'attributes': {'stats': {'DBNOs': 1,
#      'assists': 1,
#      'boosts': 3,
#      'damageDealt': 542.0505,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 1,
#      'killPlace': 8,
#      'killStreaks': 3,
#      'kills': 3,
#      'longestKill': 133.6373,
#      'name': 'KQ_ZhanDouJi',
#      'playerId': 'account.22528554f5594e39aa5f7c150d7a97a0',
#      'revives': 1,
#      'rideDistance': 4686.1523,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1771.852,
#      'vehicleDestroys': 0,
#      'walkDistance': 2252.5679,
#      'weaponsAcquired': 4,
#      'winPlace': 2},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'roster',
#    'id': '9f96f524-cadd-4151-a952-1fbcabedbb75',
#    'attributes': {'stats': {'rank': 19, 'teamId': 7},
#     'won': 'false',
#     'shardId': 'steam'},
#    'relationships': {'participants': {'data': [{'type': 'participant',
#        'id': 'b4955f69-1abf-4d39-86a8-6649119000fb'},
#       {'type': 'participant', 'id': '944c3bae-87f5-405a-a12a-e112205a8c74'},
#       {'type': 'participant', 'id': 'f6969f2d-fa67-4136-b899-50cbdb92959a'},
#       {'type': 'participant', 'id': '391d32ab-a5e9-4183-9f2e-9edeb693dd8e'}]},
#     'team': {'data': None}}},
#   {'type': 'roster',
#    'id': 'c4c310b2-d2d9-4f54-939d-57f906d43e41',
#    'attributes': {'stats': {'rank': 13, 'teamId': 5},
#     'won': 'false',
#     'shardId': 'steam'},
#    'relationships': {'team': {'data': None},
#     'participants': {'data': [{'type': 'participant',
#        'id': '689ef05e-b448-46e6-9d82-974f3b57ff47'},
#       {'type': 'participant', 'id': 'cf722fe5-9f4e-4619-98ed-2c2e9dc5e785'},
#       {'type': 'participant',
#        'id': '90280503-2d1f-4ee1-8088-ce46c17d2eb3'}]}}},
#   {'type': 'participant',
#    'id': 'ce499dce-4049-4873-9abe-255523226f04',
#    'attributes': {'shardId': 'steam',
#     'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 0,
#      'damageDealt': 0,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 56,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'SQ46',
#      'playerId': 'account.1b8f4326cdb44cd6ac1c99a3d2182e5d',
#      'revives': 0,
#      'rideDistance': 0,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 164.77,
#      'vehicleDestroys': 0,
#      'walkDistance': 275.1221,
#      'weaponsAcquired': 2,
#      'winPlace': 16},
#     'actor': ''}},
#   {'type': 'participant',
#    'id': '09847807-ba34-4ce5-865e-1c8502eb20f3',
#    'attributes': {'stats': {'DBNOs': 1,
#      'assists': 0,
#      'boosts': 3,
#      'damageDealt': 143.42299,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 4,
#      'killPlace': 34,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'Odmin',
#      'playerId': 'account.038f96e8563f4e03af57d48c684d7773',
#      'revives': 0,
#      'rideDistance': 2730.5342,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1620.235,
#      'vehicleDestroys': 0,
#      'walkDistance': 2990.3325,
#      'weaponsAcquired': 6,
#      'winPlace': 6},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '65f9cf98-da20-458f-99b8-96404e0a7b1f',
#    'attributes': {'stats': {'DBNOs': 5,
#      'assists': 0,
#      'boosts': 6,
#      'damageDealt': 700.2687,
#      'deathType': 'byplayer',
#      'headshotKills': 3,
#      'heals': 3,
#      'killPlace': 3,
#      'killStreaks': 2,
#      'kills': 6,
#      'longestKill': 248.48416,
#      'name': 'KILLer___AJ',
#      'playerId': 'account.824eb122d6a543d9a0e372ffc9657ecd',
#      'revives': 0,
#      'rideDistance': 10113.163,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1419.465,
#      'vehicleDestroys': 0,
#      'walkDistance': 1880.8004,
#      'weaponsAcquired': 10,
#      'winPlace': 5},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'roster',
#    'id': 'dc919749-e90f-431f-a02c-b5f0eff26421',
#    'attributes': {'stats': {'rank': 5, 'teamId': 20},
#     'won': 'false',
#     'shardId': 'steam'},
#    'relationships': {'team': {'data': None},
#     'participants': {'data': [{'type': 'participant',
#        'id': '65f9cf98-da20-458f-99b8-96404e0a7b1f'},
#       {'type': 'participant', 'id': '5de316f7-1ccd-4559-bb67-20e0e35206c4'},
#       {'type': 'participant', 'id': 'c9329972-106e-43e4-99aa-4e4f955528b8'},
#       {'type': 'participant',
#        'id': '0a474e26-793f-4df6-b759-de4aefb6ad70'}]}}},
#   {'type': 'participant',
#    'id': '61290c95-e1f9-414a-8cb0-2d8fadf0373d',
#    'attributes': {'actor': '',
#     'shardId': 'steam',
#     'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 0,
#      'damageDealt': 21.276686,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 38,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'Neal_No1',
#      'playerId': 'account.98a361b6ee494c9c8ae2c3f739415a84',
#      'revives': 0,
#      'rideDistance': 1393.7808,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1452.769,
#      'vehicleDestroys': 0,
#      'walkDistance': 2540.2314,
#      'weaponsAcquired': 5,
#      'winPlace': 10}}},
#   {'type': 'participant',
#    'id': 'b6589b41-bb6d-4bf1-aec3-64b487be28d0',
#    'attributes': {'stats': {'DBNOs': 1,
#      'assists': 0,
#      'boosts': 4,
#      'damageDealt': 286.08646,
#      'deathType': 'byzone',
#      'headshotKills': 0,
#      'heals': 8,
#      'killPlace': 14,
#      'killStreaks': 1,
#      'kills': 2,
#      'longestKill': 173.86224,
#      'name': 'GoatStalker',
#      'playerId': 'account.fc9fa62d67d84a33a25f29383d392e94',
#      'revives': 0,
#      'rideDistance': 324.7631,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1508.154,
#      'vehicleDestroys': 0,
#      'walkDistance': 3373.9685,
#      'weaponsAcquired': 5,
#      'winPlace': 9},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': 'a8c1bda8-b47c-441e-8bb6-4fd4a05a8383',
#    'attributes': {'shardId': 'steam',
#     'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 0,
#      'damageDealt': 77.08,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 57,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'ptz251zb',
#      'playerId': 'account.0fdde91555614333a012cc93f30d1372',
#      'revives': 0,
#      'rideDistance': 0,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 114.13,
#      'vehicleDestroys': 0,
#      'walkDistance': 22.721657,
#      'weaponsAcquired': 1,
#      'winPlace': 16},
#     'actor': ''}},
#   {'type': 'participant',
#    'id': 'a0e8ab82-9821-4887-a93f-0be0a336c599',
#    'attributes': {'shardId': 'steam',
#     'stats': {'DBNOs': 0,
#      'assists': 2,
#      'boosts': 1,
#      'damageDealt': 19.823332,
#      'deathType': 'alive',
#      'headshotKills': 0,
#      'heals': 1,
#      'killPlace': 29,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'AEPs4O4',
#      'playerId': 'account.acd6626ba55f4f128e3395a627b4d2da',
#      'revives': 1,
#      'rideDistance': 364.7301,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1780.006,
#      'vehicleDestroys': 0,
#      'walkDistance': 4597.7476,
#      'weaponsAcquired': 6,
#      'winPlace': 1},
#     'actor': ''}},
#   {'type': 'participant',
#    'id': '8f9fbcea-1efb-4675-b29d-b8d8fb403597',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 0,
#      'damageDealt': 0,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 49,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'Azarothe',
#      'playerId': 'account.c54691c19cfd49c1bbd3ce003104dc49',
#      'revives': 0,
#      'rideDistance': 4363.5767,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 917.136,
#      'vehicleDestroys': 2,
#      'walkDistance': 838.73584,
#      'weaponsAcquired': 6,
#      'winPlace': 14},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '11492cad-51f6-4502-9078-9a9c9d663097',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 1,
#      'damageDealt': 28.7,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 61,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'guibum',
#      'playerId': 'account.7fc7e4f15d65427790dea654a9b86c69',
#      'revives': 0,
#      'rideDistance': 0,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 526.759,
#      'vehicleDestroys': 0,
#      'walkDistance': 548.23486,
#      'weaponsAcquired': 4,
#      'winPlace': 17},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '48955b52-7d54-4248-86bc-435a765cb5a0',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 0,
#      'damageDealt': 57.4,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 71,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'spekture',
#      'playerId': 'account.6b46d60583254839bf6e8c3df814f115',
#      'revives': 0,
#      'rideDistance': 909.5566,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 209.896,
#      'vehicleDestroys': 0,
#      'walkDistance': 177.19878,
#      'weaponsAcquired': 2,
#      'winPlace': 20},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '66f8ae43-fa8d-46fc-a754-0bed64edea12',
#    'attributes': {'shardId': 'steam',
#     'stats': {'DBNOs': 0,
#      'assists': 1,
#      'boosts': 0,
#      'damageDealt': 10.8,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 72,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'Asin_Sira',
#      'playerId': 'account.154d4fd125a348e9a1f8df2daaabd9cb',
#      'revives': 0,
#      'rideDistance': 0,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 180.725,
#      'vehicleDestroys': 0,
#      'walkDistance': 80.953445,
#      'weaponsAcquired': 0,
#      'winPlace': 20},
#     'actor': ''}},
#   {'type': 'participant',
#    'id': '98b84ee2-fa43-4b36-8e61-5434b7088176',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 0,
#      'damageDealt': 28.202602,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 60,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'mattbarn',
#      'playerId': 'account.1093943b709c4a39b37343249ac8a65d',
#      'revives': 0,
#      'rideDistance': 0,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 634.706,
#      'vehicleDestroys': 0,
#      'walkDistance': 707.53284,
#      'weaponsAcquired': 7,
#      'winPlace': 17},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'roster',
#    'id': 'cb6eca6f-3082-4b72-9c17-96ee973e8b66',
#    'attributes': {'stats': {'rank': 16, 'teamId': 16},
#     'won': 'false',
#     'shardId': 'steam'},
#    'relationships': {'team': {'data': None},
#     'participants': {'data': [{'type': 'participant',
#        'id': 'ce499dce-4049-4873-9abe-255523226f04'},
#       {'type': 'participant', 'id': 'c14d66d2-187d-470c-904b-33c81a0909b1'},
#       {'type': 'participant', 'id': 'a8c1bda8-b47c-441e-8bb6-4fd4a05a8383'},
#       {'type': 'participant',
#        'id': '7ef8d730-f6a7-4c24-8db8-fcf956f00c01'}]}}}],
#  'links': {'self': 'https://api-origin.playbattlegrounds.com/shards/pc/matches/4c76d82b-90f7-4fd1-9ceb-97b99347e94e'},
#  'meta': {}}

# %% [markdown]
# ## Getting match telemetry data

# %% [markdown]
# <p><font size=5px>This part has been moved to the "extract_data.ipynb" notebook</font></p>
# <p><font size=4px>What is now here is for the purpose of the analysis of the data of this single match</font></p>
# <p>From here onwards, we are using the data on match 4c76d82b-90f7-4fd1-9ceb-97b99347e94e, belonging to the pc shard</p>

# %%
# get the asset id from a match
asset = response2.json()['data']['relationships']['assets']['data']
assetid = json.loads(json.dumps(asset[0]))['id']

# getting the telemetry object
for i in json.loads(json.dumps(response2.json()["included"])):
    if i["id"] == assetid:
        telemetry_link = i
telemetry_link

# getting the telemetry file for the match
url_telemetrydata = json.loads(json.dumps(telemetry_link))["attributes"]["URL"]
telemetry_response = requests.get(url_telemetrydata, headers=headers)

# %%
# UNDERSTANDING HOW EVENTS WORK
# get kills for the match (will be used to understand how location works after death)
kills = []
for i in json.loads(json.dumps(telemetry_response.json())):
    if i["_T"] == "LogPlayerKill":
        kills.append(i)
# kills

# %% [markdown]
# # <font color=red> Preparing DataFrame </font>

# %%
# RUN THIS CELL TO WORK WITH THE FILE UPLOADED IN THE REPOSITORY
# read files extracted from this as DataFrame
with open('telemetry_data/2020-04-09/pc/4c76d82b-90f7-4fd1-9ceb-97b99347e94e.json', 'r') as file:
    json_data = file.read()
    file.close()
data = []
for i in json.loads(json_data):
    if i["_T"] in ("LogPlayerPosition", "LogParachuteLanding"):
        data.append(i)

# %%
# get events data into pandas dataframe
data = pd.read_json(json.dumps(data))
data.head()
# Out:
#                          _D                 _T  \
# 0  2020-04-08T22:33:24.153Z  LogPlayerPosition
# 1  2020-04-08T22:33:24.220Z  LogPlayerPosition
# 2  2020-04-08T22:33:24.220Z  LogPlayerPosition
# 3  2020-04-08T22:33:24.287Z  LogPlayerPosition
# 4  2020-04-08T22:33:24.287Z  LogPlayerPosition
#
#                                            character         common  distance  \
# 0  {'name': 'Wenurous', 'teamId': 4, 'health': 10...  {'isGame': 0}       NaN
# 1  {'name': 'STSSEVEN', 'teamId': 11, 'health': 1...  {'isGame': 0}       NaN
# 2  {'name': 'OMGNOWAYTHATSBS', 'teamId': 8, 'heal...  {'isGame': 0}       NaN
# 3  {'name': 'LOCKLOAD007', 'teamId': 8, 'health':...  {'isGame': 0}       NaN
# 4  {'name': 'Cadenn', 'teamId': 7, 'health': 100,...  {'isGame': 0}       NaN
#
#    elapsedTime  numAlivePlayers vehicle
# 0          0.0             50.0    None
# 1          0.0             50.0    None
# 2          0.0             50.0    None
# 3          0.0             50.0    None
# 4          0.0             50.0    None

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8522 entries, 0 to 8521
# Data columns (total 8 columns):
# _D                 8522 non-null object
# _T                 8522 non-null object
# character          8522 non-null object
# common             8522 non-null object
# distance           77 non-null float64
# elapsedTime        8445 non-null float64
# numAlivePlayers    8445 non-null float64
# vehicle            1377 non-null object
# dtypes: float64(3), object(5)
# memory usage: 532.7+ KB

# %%
# copy match id to all rows and drop LogMatchDefinition event
matchid = json.loads(json_data)[0]["MatchId"]
data['MatchId'] = matchid

#reset indexes
data.reset_index(drop=True, inplace=True)
data.head()
# Out:
#                          _D                 _T  \
# 0  2020-04-08T22:33:24.153Z  LogPlayerPosition
# 1  2020-04-08T22:33:24.220Z  LogPlayerPosition
# 2  2020-04-08T22:33:24.220Z  LogPlayerPosition
# 3  2020-04-08T22:33:24.287Z  LogPlayerPosition
# 4  2020-04-08T22:33:24.287Z  LogPlayerPosition
#
#                                            character         common  distance  \
# 0  {'name': 'Wenurous', 'teamId': 4, 'health': 10...  {'isGame': 0}       NaN
# 1  {'name': 'STSSEVEN', 'teamId': 11, 'health': 1...  {'isGame': 0}       NaN
# 2  {'name': 'OMGNOWAYTHATSBS', 'teamId': 8, 'heal...  {'isGame': 0}       NaN
# 3  {'name': 'LOCKLOAD007', 'teamId': 8, 'health':...  {'isGame': 0}       NaN
# 4  {'name': 'Cadenn', 'teamId': 7, 'health': 100,...  {'isGame': 0}       NaN
#
#    elapsedTime  numAlivePlayers vehicle  \
# 0          0.0             50.0    None
# 1          0.0             50.0    None
# 2          0.0             50.0    None
# 3          0.0             50.0    None
# 4          0.0             50.0    None
#
#                                              MatchId
# 0  match.bro.official.pc-2018-06.steam.squad.na.2...
# 1  match.bro.official.pc-2018-06.steam.squad.na.2...
# 2  match.bro.official.pc-2018-06.steam.squad.na.2...
# 3  match.bro.official.pc-2018-06.steam.squad.na.2...
# 4  match.bro.official.pc-2018-06.steam.squad.na.2...

# %%
data.columns
# Out:
# Index(['_D', '_T', 'character', 'common', 'distance', 'elapsedTime',
#        'numAlivePlayers', 'vehicle', 'MatchId'],
#       dtype='object')

# %% [markdown]
# ### Extracting Player information variables

# %%
# get player information
from pandas.io.json import json_normalize
data = pd.concat([data, json_normalize(data['character'])], axis=1).drop(['character', 'zone'], axis=1)
data.head()
# Out:
#                          _D                 _T         common  distance  \
# 0  2020-04-08T22:33:24.153Z  LogPlayerPosition  {'isGame': 0}       NaN
# 1  2020-04-08T22:33:24.220Z  LogPlayerPosition  {'isGame': 0}       NaN
# 2  2020-04-08T22:33:24.220Z  LogPlayerPosition  {'isGame': 0}       NaN
# 3  2020-04-08T22:33:24.287Z  LogPlayerPosition  {'isGame': 0}       NaN
# 4  2020-04-08T22:33:24.287Z  LogPlayerPosition  {'isGame': 0}       NaN
#
#    elapsedTime  numAlivePlayers vehicle  \
# 0          0.0             50.0    None
# 1          0.0             50.0    None
# 2          0.0             50.0    None
# 3          0.0             50.0    None
# 4          0.0             50.0    None
#
#                                              MatchId  \
# 0  match.bro.official.pc-2018-06.steam.squad.na.2...
# 1  match.bro.official.pc-2018-06.steam.squad.na.2...
# 2  match.bro.official.pc-2018-06.steam.squad.na.2...
# 3  match.bro.official.pc-2018-06.steam.squad.na.2...
# 4  match.bro.official.pc-2018-06.steam.squad.na.2...
#
#                                   accountId  health  isInBlueZone  \
# 0  account.534e426ebc5643d781264f68e02f8adb   100.0         False
# 1  account.c57f3b1dd9484b238b44a68f3321dfd2   100.0         False
# 2  account.54a138a899ea43919a51de65323d9287   100.0         False
# 3  account.749c1f3bc22841ccb17fd9aa3e65bccf   100.0         False
# 4  account.fa20a446eea64586b4033135908d921a   100.0         False
#
#    isInRedZone    location.x   location.y    location.z             name  \
# 0        False   84096.40625  730290.9375   5105.000000         Wenurous
# 1        False  718799.81250  546016.3125   -620.969971         STSSEVEN
# 2        False  491143.65625  634140.8750  12665.149414  OMGNOWAYTHATSBS
# 3        False  490809.96875  634214.4375  12665.154297      LOCKLOAD007
# 4        False  718356.50000  546602.7500   -701.961487           Cadenn
#
#    ranking  teamId
# 0        0       4
# 1        0      11
# 2        0       8
# 3        0       8
# 4        0       7

# %% [markdown]
# ### Set isGame variable

# %% [markdown]
# ### Check how fast players move

# %% [markdown]
# ### Interpolate players location for all elapsed times

# %%
# check how many players' locations we have at each point in time
for i in data.elapsedTime.unique():
    obs = len(data[data['elapsedTime'] == i])
    print(f'{i} has {obs} observations')
# Out:
# 0.0 has 680 observations
# 1.0 has 21 observations
# 2.0 has 13 observations
# 3.0 has 5 observations
# 4.0 has 5 observations
# 5.0 has 7 observations
# 6.0 has 7 observations
# 7.0 has 1 observations
# 8.0 has 1 observations
# 9.0 has 6 observations
# 10.0 has 14 observations
# 11.0 has 22 observations
# 12.0 has 8 observations
# 13.0 has 5 observations
# 14.0 has 6 observations
# 15.0 has 6 observations
# 16.0 has 7 observations
# 17.0 has 1 observations
# 18.0 has 1 observations
# 19.0 has 6 observations
# 20.0 has 15 observations
# 21.0 has 22 observations
# 22.0 has 7 observations
# 23.0 has 6 observations
# 24.0 has 6 observations
# 25.0 has 5 observations
# 26.0 has 7 observations
# 27.0 has 1 observations
# 28.0 has 1 observations
# 29.0 has 7 observations
# 30.0 has 15 observations
# 31.0 has 21 observations
# 32.0 has 8 observations
# 33.0 has 5 observations
# 34.0 has 9 observations
# 35.0 has 4 observations
# 36.0 has 5 observations
# 37.0 has 1 observations
# 38.0 has 3 observations
# 39.0 has 6 observations
# 40.0 has 17 observations
# 41.0 has 19 observations
# 42.0 has 8 observations
# 43.0 has 4 observations
# 44.0 has 9 observations
# 45.0 has 5 observations
# 46.0 has 4 observations
# 47.0 has 1 observations
# 48.0 has 3 observations
# 49.0 has 9 observations
# 50.0 has 19 observations
# 51.0 has 15 observations
# 52.0 has 7 observations
# 53.0 has 4 observations
# 54.0 has 10 observations
# 55.0 has 5 observations
# 56.0 has 3 observations
# 57.0 has 1 observations
# 58.0 has 3 observations
# 59.0 has 9 observations
# 60.0 has 22 observations
# nan has 0 observations
# 61.0 has 14 observations
# 62.0 has 6 observations
# 63.0 has 4 observations
# 64.0 has 9 observations
# 65.0 has 5 observations
# 66.0 has 3 observations
# 67.0 has 1 observations
# 68.0 has 4 observations
# 69.0 has 9 observations
# 70.0 has 21 observations
# 71.0 has 15 observations
# 72.0 has 5 observations
# 73.0 has 4 observations
# 74.0 has 10 observations
# 75.0 has 6 observations
# 76.0 has 2 observations
# 78.0 has 5 observations
# 79.0 has 12 observations
# 80.0 has 20 observations
# 81.0 has 13 observations
# 82.0 has 6 observations
# 83.0 has 4 observations
# 84.0 has 8 observations
# 85.0 has 7 observations
# 86.0 has 1 observations
# 88.0 has 5 observations
# 89.0 has 13 observations
# 90.0 has 20 observations
# 91.0 has 13 observations
# 92.0 has 5 observations
# 93.0 has 5 observations
# 94.0 has 7 observations
# 95.0 has 7 observations
# 96.0 has 1 observations
# 97.0 has 1 observations
# 98.0 has 6 observations
# 99.0 has 12 observations
# 100.0 has 24 observations
# 101.0 has 8 observations
# 102.0 has 6 observations
# 103.0 has 5 observations
# 104.0 has 6 observations
# 105.0 has 7 observations
# 106.0 has 1 observations
# 107.0 has 1 observations
# 108.0 has 6 observations
# 109.0 has 15 observations
# 110.0 has 22 observations
# 111.0 has 7 observations
# 112.0 has 6 observations
# 113.0 has 8 observations
# 114.0 has 3 observations
# 115.0 has 7 observations
# 116.0 has 1 observations
# 117.0 has 2 observations
# 118.0 has 6 observations
# 119.0 has 17 observations
# 120.0 has 19 observations
# 121.0 has 8 observations
# 122.0 has 5 observations
# 123.0 has 9 observations
# 124.0 has 4 observations
# 125.0 has 5 observations
# 126.0 has 1 observations
# 127.0 has 3 observations
# 128.0 has 9 observations
# 129.0 has 16 observations
# 130.0 has 16 observations
# 131.0 has 7 observations
# 132.0 has 4 observations
# 133.0 has 10 observations
# 134.0 has 4 observations
# 135.0 has 4 observations
# 136.0 has 1 observations
# 137.0 has 3 observations
# 138.0 has 9 observations
# 139.0 has 19 observations
# 140.0 has 15 observations
# 141.0 has 5 observations
# 142.0 has 4 observations
# 143.0 has 10 observations
# 144.0 has 5 observations
# 145.0 has 3 observations
# 146.0 has 1 observations
# 147.0 has 3 observations
# 148.0 has 9 observations
# 149.0 has 21 observations
# 150.0 has 12 observations
# 151.0 has 6 observations
# 152.0 has 3 observations
# 153.0 has 10 observations
# 154.0 has 5 observations
# 155.0 has 3 observations
# 156.0 has 1 observations
# 157.0 has 4 observations
# 158.0 has 9 observations
# 159.0 has 19 observations
# 160.0 has 12 observations
# 161.0 has 6 observations
# 162.0 has 4 observations
# 163.0 has 10 observations
# 164.0 has 4 observations
# 165.0 has 3 observations
# 166.0 has 1 observations
# 167.0 has 4 observations
# 168.0 has 11 observations
# 169.0 has 19 observations
# 170.0 has 11 observations
# 171.0 has 6 observations
# 172.0 has 5 observations
# 173.0 has 8 observations
# 174.0 has 5 observations
# 175.0 has 2 observations
# 177.0 has 5 observations
# 178.0 has 13 observations
# 179.0 has 17 observations
# 180.0 has 12 observations
# 181.0 has 5 observations
# 182.0 has 4 observations
# 183.0 has 7 observations
# 184.0 has 6 observations
# 185.0 has 1 observations
# 187.0 has 5 observations
# 188.0 has 13 observations
# 189.0 has 19 observations
# 190.0 has 10 observations
# 191.0 has 5 observations
# 192.0 has 6 observations
# 193.0 has 5 observations
# 194.0 has 6 observations
# 195.0 has 1 observations
# 196.0 has 1 observations
# 197.0 has 6 observations
# 198.0 has 14 observations
# 199.0 has 19 observations
# 200.0 has 7 observations
# 201.0 has 6 observations
# 202.0 has 5 observations
# 203.0 has 5 observations
# 204.0 has 6 observations
# 205.0 has 1 observations
# 206.0 has 2 observations
# 207.0 has 6 observations
# 208.0 has 16 observations
# 209.0 has 16 observations
# 210.0 has 8 observations
# 211.0 has 5 observations
# 212.0 has 8 observations
# 213.0 has 4 observations
# 214.0 has 4 observations
# 215.0 has 1 observations
# 216.0 has 3 observations
# 217.0 has 6 observations
# 218.0 has 17 observations
# 219.0 has 13 observations
# 220.0 has 7 observations
# 221.0 has 5 observations
# 222.0 has 8 observations
# 223.0 has 4 observations
# 224.0 has 3 observations
# 225.0 has 1 observations
# 226.0 has 3 observations
# 227.0 has 9 observations
# 228.0 has 16 observations
# 229.0 has 11 observations
# 230.0 has 7 observations
# 231.0 has 4 observations
# 232.0 has 9 observations
# 233.0 has 3 observations
# 234.0 has 3 observations
# 235.0 has 1 observations
# 236.0 has 3 observations
# 237.0 has 9 observations
# 238.0 has 17 observations
# 239.0 has 12 observations
# 240.0 has 6 observations
# 241.0 has 3 observations
# 242.0 has 9 observations
# 243.0 has 4 observations
# 244.0 has 2 observations
# 245.0 has 1 observations
# 246.0 has 4 observations
# 247.0 has 9 observations
# 248.0 has 16 observations
# 249.0 has 12 observations
# 250.0 has 6 observations
# 251.0 has 4 observations
# 252.0 has 9 observations
# 253.0 has 3 observations
# 254.0 has 2 observations
# 255.0 has 1 observations
# 256.0 has 4 observations
# 257.0 has 11 observations
# 258.0 has 16 observations
# 259.0 has 11 observations
# 260.0 has 6 observations
# 261.0 has 4 observations
# 262.0 has 8 observations
# 263.0 has 5 observations
# 264.0 has 1 observations
# 266.0 has 5 observations
# 267.0 has 13 observations
# 268.0 has 14 observations
# 269.0 has 12 observations
# 270.0 has 5 observations
# 271.0 has 5 observations
# 272.0 has 6 observations
# 273.0 has 5 observations
# 274.0 has 1 observations
# 275.0 has 1 observations
# 276.0 has 6 observations
# 277.0 has 14 observations
# 278.0 has 16 observations
# 279.0 has 7 observations
# 280.0 has 6 observations
# 281.0 has 5 observations
# 282.0 has 5 observations
# 283.0 has 5 observations
# 284.0 has 1 observations
# 285.0 has 2 observations
# 286.0 has 6 observations
# 287.0 has 16 observations
# 288.0 has 13 observations
# 289.0 has 8 observations
# 290.0 has 5 observations
# 291.0 has 8 observations
# 292.0 has 4 observations
# 293.0 has 3 observations
# 294.0 has 1 observations
# 295.0 has 3 observations
# 296.0 has 6 observations
# 297.0 has 16 observations
# 298.0 has 13 observations
# 299.0 has 8 observations
# 300.0 has 4 observations
# 301.0 has 9 observations
# 302.0 has 3 observations
# 303.0 has 3 observations
# 304.0 has 1 observations
# 305.0 has 3 observations
# 306.0 has 8 observations
# 307.0 has 16 observations
# 308.0 has 13 observations
# 309.0 has 5 observations
# 310.0 has 4 observations
# 311.0 has 9 observations
# 312.0 has 4 observations
# 313.0 has 2 observations
# 314.0 has 1 observations
# 315.0 has 3 observations
# 316.0 has 9 observations
# 317.0 has 16 observations
# 318.0 has 11 observations
# 319.0 has 5 observations
# 320.0 has 4 observations
# 321.0 has 9 observations
# 322.0 has 3 observations
# 323.0 has 2 observations
# 324.0 has 1 observations
# 325.0 has 3 observations
# 326.0 has 12 observations
# 327.0 has 15 observations
# 328.0 has 8 observations
# 329.0 has 6 observations
# 330.0 has 4 observations
# 331.0 has 7 observations
# 332.0 has 5 observations
# 333.0 has 1 observations
# 335.0 has 4 observations
# 336.0 has 12 observations
# 337.0 has 14 observations
# 338.0 has 9 observations
# 339.0 has 5 observations
# 340.0 has 5 observations
# 341.0 has 6 observations
# 342.0 has 5 observations
# 343.0 has 1 observations
# 344.0 has 1 observations
# 345.0 has 5 observations
# 346.0 has 13 observations
# 347.0 has 15 observations
# 348.0 has 5 observations
# 349.0 has 6 observations
# 350.0 has 5 observations
# 351.0 has 5 observations
# 352.0 has 5 observations
# 353.0 has 1 observations
# 354.0 has 2 observations
# 355.0 has 5 observations
# 356.0 has 16 observations
# 357.0 has 11 observations
# 358.0 has 6 observations
# 359.0 has 5 observations
# 360.0 has 8 observations
# 361.0 has 4 observations
# 362.0 has 3 observations
# 363.0 has 1 observations
# 364.0 has 3 observations
# 365.0 has 5 observations
# 366.0 has 17 observations
# 367.0 has 11 observations
# 368.0 has 5 observations
# 369.0 has 4 observations
# 370.0 has 9 observations
# 371.0 has 3 observations
# 372.0 has 3 observations
# 373.0 has 1 observations
# 374.0 has 3 observations
# 375.0 has 8 observations
# 376.0 has 15 observations
# 377.0 has 11 observations
# 378.0 has 3 observations
# 379.0 has 4 observations
# 380.0 has 8 observations
# 381.0 has 4 observations
# 382.0 has 2 observations
# 383.0 has 1 observations
# 384.0 has 3 observations
# 385.0 has 8 observations
# 386.0 has 16 observations
# 387.0 has 10 observations
# 388.0 has 4 observations
# 389.0 has 4 observations
# 390.0 has 7 observations
# 391.0 has 4 observations
# 392.0 has 2 observations
# 393.0 has 1 observations
# 394.0 has 3 observations
# 395.0 has 10 observations
# 396.0 has 14 observations
# 397.0 has 10 observations
# 398.0 has 4 observations
# 399.0 has 4 observations
# 400.0 has 8 observations
# 401.0 has 3 observations
# 402.0 has 2 observations
# 403.0 has 1 observations
# 404.0 has 4 observations
# 405.0 has 11 observations
# 406.0 has 15 observations
# 407.0 has 7 observations
# 408.0 has 6 observations
# 409.0 has 5 observations
# 410.0 has 5 observations
# 411.0 has 5 observations
# 412.0 has 1 observations
# 413.0 has 1 observations
# 414.0 has 3 observations
# 415.0 has 12 observations
# 416.0 has 15 observations
# 417.0 has 7 observations
# 418.0 has 5 observations
# 419.0 has 6 observations
# 420.0 has 4 observations
# 421.0 has 5 observations
# 422.0 has 1 observations
# 423.0 has 1 observations
# 424.0 has 5 observations
# 425.0 has 14 observations
# 426.0 has 14 observations
# 427.0 has 4 observations
# 428.0 has 6 observations
# 429.0 has 6 observations
# 430.0 has 5 observations
# 431.0 has 3 observations
# 432.0 has 1 observations
# 433.0 has 2 observations
# 434.0 has 5 observations
# 435.0 has 16 observations
# 436.0 has 11 observations
# 437.0 has 5 observations
# 438.0 has 5 observations
# 439.0 has 7 observations
# 440.0 has 4 observations
# 441.0 has 3 observations
# 442.0 has 1 observations
# 443.0 has 3 observations
# 444.0 has 8 observations
# 445.0 has 14 observations
# 446.0 has 11 observations
# 447.0 has 4 observations
# 448.0 has 4 observations
# 449.0 has 8 observations
# 450.0 has 3 observations
# 451.0 has 3 observations
# 452.0 has 1 observations
# 453.0 has 3 observations
# 454.0 has 8 observations
# 455.0 has 15 observations
# 456.0 has 11 observations
# 457.0 has 3 observations
# 458.0 has 4 observations
# 459.0 has 8 observations
# 460.0 has 4 observations
# 461.0 has 2 observations
# 462.0 has 1 observations
# 463.0 has 3 observations
# 464.0 has 9 observations
# 465.0 has 15 observations
# 466.0 has 10 observations
# 467.0 has 4 observations
# 468.0 has 4 observations
# 469.0 has 8 observations
# 470.0 has 4 observations
# 471.0 has 2 observations
# 473.0 has 4 observations
# 474.0 has 12 observations
# 475.0 has 13 observations
# 476.0 has 6 observations
# 477.0 has 6 observations
# 478.0 has 4 observations
# 479.0 has 6 observations
# 480.0 has 5 observations
# 481.0 has 1 observations
# 482.0 has 1 observations
# 483.0 has 5 observations
# 484.0 has 10 observations
# 485.0 has 14 observations
# 486.0 has 6 observations
# 487.0 has 5 observations
# 488.0 has 6 observations
# 489.0 has 4 observations
# 490.0 has 5 observations
# 491.0 has 1 observations
# 492.0 has 1 observations
# 493.0 has 5 observations
# 494.0 has 15 observations
# 495.0 has 12 observations
# 496.0 has 4 observations
# 497.0 has 4 observations
# 498.0 has 6 observations
# 499.0 has 5 observations
# 500.0 has 3 observations
# 501.0 has 1 observations
# 502.0 has 3 observations
# 503.0 has 5 observations
# 504.0 has 15 observations
# 505.0 has 11 observations
# 506.0 has 3 observations
# 507.0 has 4 observations
# 508.0 has 7 observations
# 509.0 has 4 observations
# 510.0 has 3 observations
# 511.0 has 1 observations
# 512.0 has 3 observations
# 513.0 has 8 observations
# 514.0 has 15 observations
# 515.0 has 9 observations
# 516.0 has 3 observations
# 517.0 has 3 observations
# 518.0 has 8 observations
# 519.0 has 4 observations
# 520.0 has 2 observations
# 521.0 has 1 observations
# 522.0 has 3 observations
# 523.0 has 8 observations
# 524.0 has 16 observations
# 525.0 has 8 observations
# 526.0 has 3 observations
# 527.0 has 2 observations
# 528.0 has 8 observations
# 529.0 has 4 observations
# 530.0 has 2 observations
# 531.0 has 1 observations
# 532.0 has 3 observations
# 533.0 has 8 observations
# 534.0 has 16 observations
# 535.0 has 7 observations
# 536.0 has 3 observations
# 537.0 has 3 observations
# 538.0 has 8 observations
# 539.0 has 3 observations
# 540.0 has 2 observations
# 541.0 has 1 observations
# 542.0 has 3 observations
# 543.0 has 12 observations
# 544.0 has 14 observations
# 545.0 has 5 observations
# 546.0 has 4 observations
# 547.0 has 4 observations
# 548.0 has 6 observations
# 549.0 has 4 observations
# 550.0 has 2 observations
# 552.0 has 4 observations
# 553.0 has 12 observations
# 554.0 has 13 observations
# 555.0 has 6 observations
# 556.0 has 3 observations
# 557.0 has 5 observations
# 558.0 has 5 observations
# 559.0 has 5 observations
# 560.0 has 1 observations
# 561.0 has 1 observations
# 562.0 has 5 observations
# 563.0 has 10 observations
# 564.0 has 14 observations
# 565.0 has 5 observations
# 566.0 has 3 observations
# 567.0 has 6 observations
# 568.0 has 4 observations
# 569.0 has 5 observations
# 570.0 has 1 observations
# 571.0 has 1 observations
# 572.0 has 5 observations
# 573.0 has 14 observations
# 574.0 has 12 observations
# 575.0 has 2 observations
# 576.0 has 4 observations
# 577.0 has 5 observations
# 578.0 has 4 observations
# 579.0 has 5 observations
# 580.0 has 1 observations
# 581.0 has 1 observations
# 582.0 has 6 observations
# 583.0 has 15 observations
# 584.0 has 10 observations
# 585.0 has 3 observations
# 586.0 has 3 observations
# 587.0 has 7 observations
# 588.0 has 4 observations
# 589.0 has 3 observations
# 590.0 has 1 observations
# 591.0 has 3 observations
# 592.0 has 8 observations
# 593.0 has 14 observations
# 594.0 has 8 observations
# 595.0 has 3 observations
# 596.0 has 2 observations
# 597.0 has 8 observations
# 598.0 has 3 observations
# 599.0 has 3 observations
# 600.0 has 1 observations
# 601.0 has 3 observations
# 602.0 has 8 observations
# 603.0 has 15 observations
# 604.0 has 7 observations
# 605.0 has 3 observations
# 606.0 has 2 observations
# 607.0 has 8 observations
# 608.0 has 4 observations
# 609.0 has 2 observations
# 610.0 has 1 observations
# 611.0 has 3 observations
# 612.0 has 12 observations
# 613.0 has 13 observations
# 614.0 has 5 observations
# 615.0 has 4 observations
# 616.0 has 4 observations
# 617.0 has 6 observations
# 618.0 has 5 observations
# 619.0 has 1 observations
# 621.0 has 4 observations
# 622.0 has 12 observations
# 623.0 has 12 observations
# 624.0 has 6 observations
# 625.0 has 3 observations
# 626.0 has 5 observations
# 627.0 has 5 observations
# 628.0 has 5 observations
# 629.0 has 1 observations
# 630.0 has 1 observations
# 631.0 has 5 observations
# 632.0 has 9 observations
# 633.0 has 13 observations
# 634.0 has 5 observations
# 635.0 has 4 observations
# 636.0 has 5 observations
# 637.0 has 4 observations
# 638.0 has 5 observations
# 639.0 has 1 observations
# 640.0 has 1 observations
# 641.0 has 5 observations
# 642.0 has 14 observations
# 643.0 has 10 observations
# 644.0 has 3 observations
# 645.0 has 3 observations
# 646.0 has 5 observations
# 647.0 has 5 observations
# 648.0 has 3 observations
# 649.0 has 1 observations
# 650.0 has 3 observations
# 651.0 has 5 observations
# 652.0 has 13 observations
# 653.0 has 9 observations
# 654.0 has 4 observations
# 655.0 has 2 observations
# 656.0 has 6 observations
# 657.0 has 4 observations
# 658.0 has 3 observations
# 659.0 has 1 observations
# 660.0 has 3 observations
# 661.0 has 8 observations
# 662.0 has 13 observations
# 663.0 has 7 observations
# 664.0 has 3 observations
# 665.0 has 2 observations
# 666.0 has 7 observations
# 667.0 has 4 observations
# 668.0 has 2 observations
# 669.0 has 1 observations
# 670.0 has 3 observations
# 671.0 has 8 observations
# 672.0 has 14 observations
# 673.0 has 6 observations
# 674.0 has 3 observations
# 675.0 has 3 observations
# 676.0 has 6 observations
# 677.0 has 4 observations
# 678.0 has 2 observations
# 679.0 has 1 observations
# 680.0 has 3 observations
# 681.0 has 10 observations
# 682.0 has 12 observations
# 683.0 has 6 observations
# 684.0 has 4 observations
# 685.0 has 2 observations
# 686.0 has 7 observations
# 687.0 has 3 observations
# 688.0 has 2 observations
# 689.0 has 1 observations
# 690.0 has 3 observations
# 691.0 has 10 observations
# 692.0 has 13 observations
# 693.0 has 5 observations
# 694.0 has 4 observations
# 695.0 has 2 observations
# 696.0 has 7 observations
# 697.0 has 4 observations
# 698.0 has 2 observations
# 700.0 has 4 observations
# 701.0 has 11 observations
# 702.0 has 12 observations
# 703.0 has 5 observations
# 704.0 has 3 observations
# 705.0 has 4 observations
# 706.0 has 5 observations
# 707.0 has 5 observations
# 708.0 has 1 observations
# 710.0 has 4 observations
# 711.0 has 11 observations
# 712.0 has 12 observations
# 713.0 has 5 observations
# 714.0 has 3 observations
# 715.0 has 5 observations
# 716.0 has 4 observations
# 717.0 has 5 observations
# 718.0 has 1 observations
# 719.0 has 1 observations
# 720.0 has 5 observations
# 721.0 has 13 observations
# 722.0 has 11 observations
# 723.0 has 2 observations
# 724.0 has 4 observations
# 725.0 has 4 observations
# 726.0 has 4 observations
# 727.0 has 5 observations
# 728.0 has 1 observations
# 729.0 has 1 observations
# 730.0 has 5 observations
# 731.0 has 14 observations
# 732.0 has 10 observations
# 733.0 has 3 observations
# 734.0 has 3 observations
# 735.0 has 5 observations
# 736.0 has 5 observations
# 737.0 has 3 observations
# 738.0 has 1 observations
# 739.0 has 3 observations
# 740.0 has 8 observations
# 741.0 has 12 observations
# 742.0 has 8 observations
# 743.0 has 3 observations
# 744.0 has 2 observations
# 745.0 has 7 observations
# 746.0 has 3 observations
# 747.0 has 3 observations
# 748.0 has 1 observations
# 749.0 has 3 observations
# 750.0 has 8 observations
# 751.0 has 13 observations
# 752.0 has 7 observations
# 753.0 has 3 observations
# 754.0 has 2 observations
# 755.0 has 7 observations
# 756.0 has 4 observations
# 757.0 has 2 observations
# 758.0 has 1 observations
# 759.0 has 3 observations
# 760.0 has 8 observations
# 761.0 has 14 observations
# 762.0 has 6 observations
# 763.0 has 3 observations
# 764.0 has 3 observations
# 765.0 has 7 observations
# 766.0 has 4 observations
# 767.0 has 2 observations
# 769.0 has 4 observations
# 770.0 has 10 observations
# 771.0 has 13 observations
# 772.0 has 4 observations
# 773.0 has 4 observations
# 774.0 has 3 observations
# 775.0 has 6 observations
# 776.0 has 5 observations
# 779.0 has 4 observations
# 780.0 has 11 observations
# 781.0 has 12 observations
# 782.0 has 5 observations
# 783.0 has 3 observations
# 784.0 has 4 observations
# 785.0 has 5 observations
# 786.0 has 4 observations
# 788.0 has 1 observations
# 789.0 has 5 observations
# 790.0 has 12 observations
# 791.0 has 12 observations
# 792.0 has 2 observations
# 793.0 has 4 observations
# 794.0 has 4 observations
# 795.0 has 3 observations
# 796.0 has 3 observations
# 798.0 has 1 observations
# 799.0 has 5 observations
# 800.0 has 14 observations
# 801.0 has 10 observations
# 802.0 has 3 observations
# 803.0 has 3 observations
# 804.0 has 6 observations
# 805.0 has 2 observations
# 806.0 has 1 observations
# 808.0 has 3 observations
# 809.0 has 8 observations
# 810.0 has 12 observations
# 811.0 has 8 observations
# 812.0 has 3 observations
# 813.0 has 2 observations
# 814.0 has 7 observations
# 815.0 has 1 observations
# 816.0 has 1 observations
# 818.0 has 3 observations
# 819.0 has 8 observations
# 820.0 has 14 observations
# 821.0 has 6 observations
# 822.0 has 3 observations
# 823.0 has 2 observations
# 824.0 has 7 observations
# 825.0 has 1 observations
# 826.0 has 1 observations
# 828.0 has 3 observations
# 829.0 has 8 observations
# 830.0 has 14 observations
# 831.0 has 6 observations
# 832.0 has 3 observations
# 833.0 has 3 observations
# 834.0 has 6 observations
# 835.0 has 1 observations
# 836.0 has 1 observations
# 838.0 has 3 observations
# 839.0 has 9 observations
# 840.0 has 13 observations
# 841.0 has 4 observations
# 842.0 has 4 observations
# 843.0 has 2 observations
# 844.0 has 6 observations
# 845.0 has 2 observations
# 848.0 has 4 observations
# 849.0 has 10 observations
# 850.0 has 12 observations
# 851.0 has 3 observations
# 852.0 has 3 observations
# 853.0 has 4 observations
# 854.0 has 4 observations
# 855.0 has 2 observations
# 857.0 has 1 observations
# 858.0 has 3 observations
# 859.0 has 11 observations
# 860.0 has 12 observations
# 861.0 has 2 observations
# 862.0 has 4 observations
# 863.0 has 4 observations
# 864.0 has 3 observations
# 865.0 has 2 observations
# 867.0 has 1 observations
# 868.0 has 5 observations
# 869.0 has 13 observations
# 870.0 has 8 observations
# 871.0 has 2 observations
# 872.0 has 4 observations
# 873.0 has 5 observations
# 874.0 has 2 observations
# 875.0 has 2 observations
# 877.0 has 2 observations
# 878.0 has 5 observations
# 879.0 has 13 observations
# 880.0 has 7 observations
# 881.0 has 3 observations
# 882.0 has 3 observations
# 883.0 has 6 observations
# 884.0 has 2 observations
# 885.0 has 1 observations
# 887.0 has 3 observations
# 888.0 has 8 observations
# 889.0 has 11 observations
# 890.0 has 6 observations
# 891.0 has 3 observations
# 892.0 has 2 observations
# 893.0 has 7 observations
# 894.0 has 1 observations
# 895.0 has 1 observations
# 897.0 has 3 observations
# 898.0 has 8 observations
# 899.0 has 13 observations
# 900.0 has 4 observations
# 901.0 has 3 observations
# 902.0 has 2 observations
# 903.0 has 7 observations
# 904.0 has 1 observations
# 905.0 has 1 observations
# 907.0 has 3 observations
# 908.0 has 8 observations
# 909.0 has 13 observations
# 910.0 has 3 observations
# 911.0 has 3 observations
# 912.0 has 3 observations
# 913.0 has 6 observations
# 914.0 has 1 observations
# 915.0 has 1 observations
# 917.0 has 3 observations
# 918.0 has 8 observations
# 919.0 has 13 observations
# 920.0 has 3 observations
# 921.0 has 3 observations
# 922.0 has 3 observations
# 923.0 has 5 observations
# 924.0 has 2 observations
# 927.0 has 4 observations
# 928.0 has 10 observations
# 929.0 has 12 observations
# 930.0 has 1 observations
# 931.0 has 3 observations
# 932.0 has 4 observations
# 933.0 has 4 observations
# 934.0 has 2 observations
# 936.0 has 1 observations
# 937.0 has 5 observations
# 938.0 has 11 observations
# 939.0 has 10 observations
# 941.0 has 4 observations
# 942.0 has 4 observations
# 943.0 has 3 observations
# 944.0 has 2 observations
# 946.0 has 1 observations
# 947.0 has 6 observations
# 948.0 has 12 observations
# 949.0 has 8 observations
# 950.0 has 1 observations
# 951.0 has 3 observations
# 952.0 has 5 observations
# 953.0 has 3 observations
# 954.0 has 1 observations
# 956.0 has 3 observations
# 957.0 has 5 observations
# 958.0 has 12 observations
# 959.0 has 7 observations
# 960.0 has 1 observations
# 961.0 has 3 observations
# 962.0 has 6 observations
# 963.0 has 2 observations
# 964.0 has 1 observations
# 966.0 has 3 observations
# 967.0 has 8 observations
# 968.0 has 11 observations
# 969.0 has 5 observations
# 970.0 has 2 observations
# 971.0 has 2 observations
# 972.0 has 7 observations
# 973.0 has 1 observations
# 974.0 has 1 observations
# 976.0 has 3 observations
# 977.0 has 8 observations
# 978.0 has 13 observations
# 979.0 has 3 observations
# 980.0 has 2 observations
# 981.0 has 2 observations
# 982.0 has 7 observations
# 983.0 has 1 observations
# 984.0 has 1 observations
# 986.0 has 3 observations
# 987.0 has 8 observations
# 988.0 has 13 observations
# 989.0 has 3 observations
# 990.0 has 2 observations
# 991.0 has 3 observations
# 992.0 has 6 observations
# 993.0 has 1 observations
# 994.0 has 1 observations
# 996.0 has 3 observations
# 997.0 has 9 observations
# 998.0 has 11 observations
# 999.0 has 2 observations
# 1000.0 has 3 observations
# 1001.0 has 3 observations
# 1002.0 has 5 observations
# 1003.0 has 2 observations
# 1006.0 has 4 observations
# 1007.0 has 9 observations
# 1008.0 has 11 observations
# 1009.0 has 1 observations
# 1010.0 has 3 observations
# 1011.0 has 3 observations
# 1012.0 has 5 observations
# 1013.0 has 2 observations
# 1016.0 has 4 observations
# 1017.0 has 10 observations
# 1018.0 has 11 observations
# 1020.0 has 3 observations
# 1021.0 has 5 observations
# 1022.0 has 3 observations
# 1023.0 has 2 observations
# 1025.0 has 1 observations
# 1026.0 has 5 observations
# 1027.0 has 12 observations
# 1028.0 has 7 observations
# 1029.0 has 1 observations
# 1030.0 has 3 observations
# 1031.0 has 5 observations
# 1032.0 has 2 observations
# 1033.0 has 2 observations
# 1035.0 has 3 observations
# 1036.0 has 5 observations
# 1037.0 has 11 observations
# 1038.0 has 6 observations
# 1039.0 has 1 observations
# 1040.0 has 3 observations
# 1041.0 has 6 observations
# 1042.0 has 2 observations
# 1043.0 has 1 observations
# 1045.0 has 3 observations
# 1046.0 has 8 observations
# 1047.0 has 9 observations
# 1048.0 has 5 observations
# 1049.0 has 2 observations
# 1050.0 has 2 observations
# 1051.0 has 7 observations
# 1052.0 has 1 observations
# 1053.0 has 1 observations
# 1055.0 has 3 observations
# 1056.0 has 8 observations
# 1057.0 has 11 observations
# 1058.0 has 3 observations
# 1059.0 has 2 observations
# 1060.0 has 2 observations
# 1061.0 has 7 observations
# 1062.0 has 1 observations
# 1063.0 has 1 observations
# 1065.0 has 3 observations
# 1066.0 has 8 observations
# 1067.0 has 11 observations
# 1068.0 has 3 observations
# 1069.0 has 2 observations
# 1070.0 has 3 observations
# 1071.0 has 6 observations
# 1072.0 has 2 observations
# 1075.0 has 4 observations
# 1076.0 has 10 observations
# 1077.0 has 10 observations
# 1078.0 has 1 observations
# 1079.0 has 3 observations
# 1080.0 has 4 observations
# 1081.0 has 4 observations
# 1082.0 has 2 observations
# 1084.0 has 1 observations
# 1085.0 has 5 observations
# 1086.0 has 8 observations
# 1087.0 has 11 observations
# 1089.0 has 4 observations
# 1090.0 has 4 observations
# 1091.0 has 3 observations
# 1092.0 has 1 observations
# 1094.0 has 1 observations
# 1095.0 has 5 observations
# 1096.0 has 12 observations
# 1097.0 has 6 observations
# 1098.0 has 1 observations
# 1099.0 has 3 observations
# 1100.0 has 5 observations
# 1101.0 has 3 observations
# 1104.0 has 3 observations
# 1105.0 has 5 observations
# 1106.0 has 11 observations
# 1107.0 has 5 observations
# 1108.0 has 1 observations
# 1109.0 has 3 observations
# 1110.0 has 6 observations
# 1111.0 has 2 observations
# 1114.0 has 3 observations
# 1115.0 has 8 observations
# 1116.0 has 10 observations
# 1117.0 has 2 observations
# 1118.0 has 2 observations
# 1119.0 has 2 observations
# 1120.0 has 7 observations
# 1121.0 has 1 observations
# 1124.0 has 3 observations
# 1125.0 has 8 observations
# 1126.0 has 11 observations
# 1127.0 has 1 observations
# 1128.0 has 2 observations
# 1129.0 has 2 observations
# 1130.0 has 7 observations
# 1131.0 has 1 observations
# 1134.0 has 2 observations
# 1135.0 has 8 observations
# 1136.0 has 11 observations
# 1137.0 has 1 observations
# 1138.0 has 2 observations
# 1139.0 has 3 observations
# 1140.0 has 6 observations
# 1141.0 has 1 observations
# 1144.0 has 2 observations
# 1145.0 has 10 observations
# 1146.0 has 9 observations
# 1147.0 has 1 observations
# 1148.0 has 3 observations
# 1149.0 has 3 observations
# 1150.0 has 5 observations
# 1151.0 has 1 observations
# 1154.0 has 3 observations
# 1155.0 has 10 observations
# 1156.0 has 8 observations
# 1157.0 has 1 observations
# 1158.0 has 3 observations
# 1159.0 has 4 observations
# 1160.0 has 4 observations
# 1161.0 has 1 observations
# 1163.0 has 1 observations
# 1164.0 has 2 observations
# 1165.0 has 10 observations
# 1166.0 has 9 observations
# 1168.0 has 3 observations
# 1169.0 has 5 observations
# 1170.0 has 3 observations
# 1171.0 has 1 observations
# 1173.0 has 1 observations
# 1174.0 has 4 observations
# 1175.0 has 12 observations
# 1176.0 has 5 observations
# 1178.0 has 4 observations
# 1179.0 has 4 observations
# 1180.0 has 3 observations
# 1181.0 has 1 observations
# 1183.0 has 1 observations
# 1184.0 has 5 observations
# 1185.0 has 11 observations
# 1186.0 has 5 observations
# 1187.0 has 1 observations
# 1188.0 has 3 observations
# 1189.0 has 6 observations
# 1190.0 has 2 observations
# 1193.0 has 2 observations
# 1194.0 has 8 observations
# 1195.0 has 10 observations
# 1196.0 has 2 observations
# 1197.0 has 2 observations
# 1198.0 has 2 observations
# 1199.0 has 7 observations
# 1200.0 has 1 observations
# 1203.0 has 2 observations
# 1204.0 has 8 observations
# 1205.0 has 11 observations
# 1206.0 has 1 observations
# 1207.0 has 2 observations
# 1208.0 has 1 observations
# 1209.0 has 6 observations
# 1210.0 has 1 observations
# 1213.0 has 2 observations
# 1214.0 has 9 observations
# 1215.0 has 10 observations
# 1216.0 has 1 observations
# 1217.0 has 2 observations
# 1218.0 has 2 observations
# 1219.0 has 5 observations
# 1220.0 has 1 observations
# 1223.0 has 3 observations
# 1224.0 has 10 observations
# 1225.0 has 9 observations
# 1227.0 has 2 observations
# 1228.0 has 4 observations
# 1229.0 has 3 observations
# 1230.0 has 1 observations
# 1232.0 has 1 observations
# 1233.0 has 4 observations
# 1234.0 has 12 observations
# 1235.0 has 5 observations
# 1236.0 has 1 observations
# 1237.0 has 2 observations
# 1238.0 has 5 observations
# 1239.0 has 2 observations
# 1242.0 has 2 observations
# 1243.0 has 5 observations
# 1244.0 has 11 observations
# 1245.0 has 4 observations
# 1246.0 has 2 observations
# 1247.0 has 1 observations
# 1248.0 has 6 observations
# 1249.0 has 1 observations
# 1252.0 has 2 observations
# 1253.0 has 8 observations
# 1254.0 has 10 observations
# 1255.0 has 2 observations
# 1256.0 has 2 observations
# 1257.0 has 1 observations
# 1258.0 has 6 observations
# 1259.0 has 1 observations
# 1262.0 has 2 observations
# 1263.0 has 8 observations
# 1264.0 has 11 observations
# 1265.0 has 1 observations
# 1266.0 has 2 observations
# 1267.0 has 1 observations
# 1268.0 has 5 observations
# 1269.0 has 1 observations
# 1272.0 has 3 observations
# 1273.0 has 9 observations
# 1274.0 has 9 observations
# 1275.0 has 1 observations
# 1276.0 has 2 observations
# 1277.0 has 2 observations
# 1278.0 has 4 observations
# 1279.0 has 1 observations
# 1282.0 has 3 observations
# 1283.0 has 10 observations
# 1284.0 has 8 observations
# 1285.0 has 1 observations
# 1286.0 has 2 observations
# 1287.0 has 3 observations
# 1288.0 has 3 observations
# 1289.0 has 1 observations
# 1292.0 has 3 observations
# 1293.0 has 9 observations
# 1294.0 has 8 observations
# 1295.0 has 1 observations
# 1296.0 has 2 observations
# 1297.0 has 3 observations
# 1298.0 has 3 observations
# 1299.0 has 1 observations
# 1301.0 has 1 observations
# 1302.0 has 4 observations
# 1303.0 has 11 observations
# 1304.0 has 5 observations
# 1305.0 has 1 observations
# 1306.0 has 2 observations
# 1307.0 has 3 observations
# 1308.0 has 3 observations
# 1311.0 has 2 observations
# 1312.0 has 7 observations
# 1313.0 has 9 observations
# 1314.0 has 3 observations
# 1315.0 has 2 observations
# 1316.0 has 1 observations
# 1317.0 has 5 observations
# 1318.0 has 1 observations
# 1321.0 has 2 observations
# 1322.0 has 7 observations
# 1323.0 has 10 observations
# 1324.0 has 2 observations
# 1325.0 has 2 observations
# 1326.0 has 1 observations
# 1327.0 has 5 observations
# 1328.0 has 1 observations
# 1331.0 has 2 observations
# 1332.0 has 7 observations
# 1333.0 has 11 observations
# 1334.0 has 1 observations
# 1335.0 has 2 observations
# 1336.0 has 1 observations
# 1337.0 has 5 observations
# 1338.0 has 1 observations
# 1341.0 has 2 observations
# 1342.0 has 8 observations
# 1343.0 has 10 observations
# 1344.0 has 1 observations
# 1345.0 has 2 observations
# 1346.0 has 2 observations
# 1347.0 has 4 observations
# 1348.0 has 1 observations
# 1351.0 has 3 observations
# 1352.0 has 9 observations
# 1353.0 has 8 observations
# 1354.0 has 1 observations
# 1355.0 has 2 observations
# 1356.0 has 3 observations
# 1357.0 has 3 observations
# 1358.0 has 1 observations
# 1360.0 has 1 observations
# 1361.0 has 4 observations
# 1362.0 has 9 observations
# 1363.0 has 7 observations
# 1365.0 has 3 observations
# 1366.0 has 2 observations
# 1367.0 has 2 observations
# 1368.0 has 1 observations
# 1370.0 has 1 observations
# 1371.0 has 5 observations
# 1372.0 has 10 observations
# 1373.0 has 5 observations
# 1374.0 has 1 observations
# 1375.0 has 2 observations
# 1376.0 has 3 observations
# 1377.0 has 1 observations
# 1380.0 has 2 observations
# 1381.0 has 6 observations
# 1382.0 has 10 observations
# 1383.0 has 3 observations
# 1384.0 has 2 observations
# 1385.0 has 1 observations
# 1386.0 has 3 observations
# 1387.0 has 1 observations
# 1390.0 has 2 observations
# 1391.0 has 7 observations
# 1392.0 has 10 observations
# 1393.0 has 2 observations
# 1394.0 has 2 observations
# 1395.0 has 1 observations
# 1396.0 has 3 observations
# 1397.0 has 1 observations
# 1400.0 has 2 observations
# 1401.0 has 7 observations
# 1402.0 has 11 observations
# 1403.0 has 1 observations
# 1404.0 has 2 observations
# 1405.0 has 1 observations
# 1406.0 has 3 observations
# 1407.0 has 1 observations
# 1410.0 has 3 observations
# 1411.0 has 9 observations
# 1412.0 has 8 observations
# 1413.0 has 1 observations
# 1414.0 has 2 observations
# 1415.0 has 2 observations
# 1416.0 has 2 observations
# 1417.0 has 1 observations
# 1419.0 has 1 observations
# 1420.0 has 2 observations
# 1421.0 has 9 observations
# 1422.0 has 9 observations
# 1424.0 has 2 observations
# 1425.0 has 3 observations
# 1426.0 has 1 observations
# 1427.0 has 1 observations
# 1429.0 has 1 observations
# 1430.0 has 4 observations
# 1431.0 has 10 observations
# 1432.0 has 6 observations
# 1433.0 has 1 observations
# 1434.0 has 2 observations
# 1435.0 has 2 observations
# 1436.0 has 1 observations
# 1437.0 has 1 observations
# 1439.0 has 1 observations
# 1440.0 has 5 observations
# 1441.0 has 11 observations
# 1442.0 has 3 observations
# 1443.0 has 2 observations
# 1444.0 has 1 observations
# 1445.0 has 3 observations
# 1446.0 has 1 observations
# 1449.0 has 2 observations
# 1450.0 has 7 observations
# 1451.0 has 10 observations
# 1452.0 has 1 observations
# 1453.0 has 2 observations
# 1454.0 has 1 observations
# 1455.0 has 3 observations
# 1456.0 has 1 observations
# 1459.0 has 2 observations
# 1460.0 has 6 observations
# 1461.0 has 10 observations
# 1462.0 has 1 observations
# 1463.0 has 2 observations
# 1464.0 has 1 observations
# 1465.0 has 3 observations
# 1466.0 has 1 observations
# 1469.0 has 2 observations
# 1470.0 has 6 observations
# 1471.0 has 10 observations
# 1472.0 has 1 observations
# 1473.0 has 2 observations
# 1474.0 has 1 observations
# 1475.0 has 3 observations
# 1479.0 has 3 observations
# 1480.0 has 7 observations
# 1481.0 has 8 observations
# 1482.0 has 1 observations
# 1483.0 has 2 observations
# 1484.0 has 2 observations
# 1485.0 has 2 observations
# 1489.0 has 3 observations
# 1490.0 has 8 observations
# 1491.0 has 8 observations
# 1493.0 has 2 observations
# 1494.0 has 3 observations
# 1495.0 has 1 observations
# 1499.0 has 4 observations
# 1500.0 has 8 observations
# 1501.0 has 4 observations
# 1503.0 has 3 observations
# 1504.0 has 2 observations
# 1505.0 has 1 observations
# 1509.0 has 2 observations
# 1510.0 has 8 observations
# 1511.0 has 3 observations
# 1512.0 has 1 observations
# 1513.0 has 2 observations
# 1514.0 has 3 observations
# 1519.0 has 3 observations
# 1520.0 has 7 observations
# 1521.0 has 2 observations
# 1522.0 has 2 observations
# 1523.0 has 1 observations
# 1524.0 has 3 observations
# 1529.0 has 4 observations
# 1530.0 has 7 observations
# 1531.0 has 1 observations
# 1532.0 has 1 observations
# 1533.0 has 1 observations
# 1534.0 has 3 observations
# 1539.0 has 4 observations
# 1540.0 has 6 observations
# 1541.0 has 1 observations
# 1542.0 has 1 observations
# 1543.0 has 1 observations
# 1544.0 has 3 observations
# 1549.0 has 4 observations
# 1550.0 has 6 observations
# 1551.0 has 1 observations
# 1552.0 has 1 observations
# 1553.0 has 1 observations
# 1554.0 has 3 observations
# 1558.0 has 1 observations
# 1559.0 has 5 observations
# 1560.0 has 4 observations
# 1561.0 has 1 observations
# 1562.0 has 1 observations
# 1563.0 has 3 observations
# 1564.0 has 1 observations
# 1568.0 has 2 observations
# 1569.0 has 4 observations
# 1570.0 has 5 observations
# 1572.0 has 1 observations
# 1573.0 has 3 observations
# 1574.0 has 1 observations
# 1578.0 has 2 observations
# 1579.0 has 8 observations
# 1580.0 has 1 observations
# 1582.0 has 2 observations
# 1583.0 has 2 observations
# 1584.0 has 1 observations
# 1588.0 has 2 observations
# 1589.0 has 7 observations
# 1590.0 has 1 observations
# 1591.0 has 1 observations
# 1592.0 has 1 observations
# 1593.0 has 3 observations
# 1598.0 has 3 observations
# 1599.0 has 6 observations
# 1600.0 has 1 observations
# 1601.0 has 1 observations
# 1602.0 has 1 observations
# 1603.0 has 3 observations
# 1608.0 has 4 observations
# 1609.0 has 5 observations
# 1610.0 has 1 observations
# 1611.0 has 1 observations
# 1612.0 has 1 observations
# 1613.0 has 3 observations
# 1618.0 has 4 observations
# 1619.0 has 4 observations
# 1620.0 has 1 observations
# 1621.0 has 1 observations
# 1622.0 has 1 observations
# 1623.0 has 3 observations
# 1628.0 has 2 observations
# 1629.0 has 4 observations
# 1630.0 has 1 observations
# 1631.0 has 1 observations
# 1632.0 has 1 observations
# 1633.0 has 3 observations
# 1638.0 has 3 observations
# 1639.0 has 3 observations
# 1640.0 has 1 observations
# 1641.0 has 1 observations
# 1642.0 has 2 observations
# 1643.0 has 2 observations
# 1648.0 has 3 observations
# 1649.0 has 4 observations
# 1651.0 has 1 observations
# 1652.0 has 3 observations
# 1653.0 has 1 observations
# 1658.0 has 4 observations
# 1659.0 has 1 observations
# 1660.0 has 1 observations
# 1661.0 has 1 observations
# 1662.0 has 2 observations
# 1663.0 has 1 observations
# 1668.0 has 4 observations
# 1669.0 has 1 observations
# 1670.0 has 1 observations
# 1671.0 has 1 observations
# 1672.0 has 3 observations
# 1678.0 has 4 observations
# 1679.0 has 1 observations
# 1680.0 has 1 observations
# 1681.0 has 1 observations
# 1682.0 has 3 observations
# 1688.0 has 4 observations
# 1689.0 has 1 observations
# 1690.0 has 1 observations
# 1691.0 has 1 observations
# 1692.0 has 3 observations
# 1698.0 has 2 observations
# 1699.0 has 1 observations
# 1700.0 has 1 observations
# 1701.0 has 1 observations
# 1702.0 has 3 observations
# 1708.0 has 2 observations
# 1709.0 has 1 observations
# 1711.0 has 1 observations
# 1712.0 has 3 observations
# 1717.0 has 1 observations
# 1718.0 has 1 observations
# 1719.0 has 1 observations
# 1721.0 has 3 observations
# 1722.0 has 1 observations
# 1727.0 has 2 observations
# 1728.0 has 1 observations
# 1730.0 has 1 observations
# 1731.0 has 2 observations
# 1732.0 has 1 observations
# 1737.0 has 2 observations
# 1738.0 has 1 observations
# 1740.0 has 1 observations
# 1741.0 has 3 observations
# 1746.0 has 19 observations

# %%
data.name.unique()
# Out:
# array(['Wenurous', 'STSSEVEN', 'OMGNOWAYTHATSBS', 'LOCKLOAD007', 'Cadenn',
#        'WishLucy', 'Kev1nMo', 'IzaDiamond', 'AeJiGooYo', 'Bougieee',
#        'RUCY06', 'DeathSs_LiuDeHua', 'EDS_SugarDady-', 'molahhh',
#        'AwesomeSStarry', 'AEPs4O4', 'Odmin', '10Baerini', 'Tiamo_zer',
#        'spekture', 'Bubbabear85', 'ChiWoDaDiao-', 'Youlaoban', 'Mac_1205',
#        'Neal_No1', 'Asin_Sira', 'Dyrand', 'boujeeeee', 'THE_IRONMAFIA',
#        'SLQY-Fish_God', 'Jubly', 'BIU-DDDSJ', 'AhYeahAhYeah',
#        'YEzi_YearSzy', 'wvwi21', '91VinsmokeSanjii', 'Landpuss',
#        'DougDimmadab', 'heysasa', 'L4_Desweet', 'lovemysister', 'AKA447',
#        'HITECHPLUMBER69', 'KillerDong7', 'GGHumannn', 'ReaPer_LiQAQ',
#        '7ooc_-_', 'Thursty1991', 'SneakyFokker', 'XxGoldenFlashxX',
#        'JC-Steve', 'VX15872277853', 'SLyx7cIOs', 'guibum', 'FriedeggMan',
#        'Noir_Fox', 'ptz251zb', 'chewy7318', 'SQ46', 'jtbullet',
#        'SoloHide', 'bbangya-x2', 'peppermlnt', 'MiracleMan74',
#        'GoatStalker', 'riteintheas', 'Ryjack22', '8255', 'G7_WenG',
#        '8344', 'KILLer___AJ', 'kfox7197', 'Lavinn-', 'CALLAHYM',
#        'Badbart314', 'duoduobaby0613', 'KQ_ZhanDouJi', 'Elessare',
#        '7Burial', 'The_Bryonic_Man', 'Bob_Roberts', 'Solomon5968', '2092',
#        'PannaCottaOVO', 'D4NoK_Yz', 'INOV77', 'PinaColadaOVO', 'Azarothe',
#        'Faxe99', 'Mondoja', 'dxnub', 'Dancingly', 'BLAVKMUSIKPCXB',
#        'Fudorin', 'fuji_-_', 'mattbarn', 'Jesse_yjho', 'Diesvtfocus',
#        'HotDoggHands', 'LDrai29'], dtype=object)

# %% [markdown]
# ### Get Collaboration information

# %%
# encode player names
players = data[['name','teamId']].drop_duplicates()
players = players.sort_values('teamId').reset_index().drop(['index'], axis=1)
players
# Out:
#                 name  teamId
# 0              dxnub       1
# 1           Mac_1205       1
# 2           spekture       1
# 3          Asin_Sira       1
# 4    HITECHPLUMBER69       2
# 5              Odmin       2
# 6      THE_IRONMAFIA       2
# 7           Neal_No1       2
# 8             RUCY06       3
# 9           WishLucy       3
# 10        IzaDiamond       3
# 11         AeJiGooYo       3
# 12    AwesomeSStarry       4
# 13          Wenurous       4
# 14          Bougieee       4
# 15         boujeeeee       4
# 16         Youlaoban       5
# 17         Tiamo_zer       5
# 18  DeathSs_LiuDeHua       5
# 19      ChiWoDaDiao-       5
# 20      YEzi_YearSzy       6
# 21         SLyx7cIOs       6
# 22           AEPs4O4       6
# 23           Kev1nMo       6
# 24           heysasa       7
# 25            Cadenn       7
# 26        L4_Desweet       7
# 27      AhYeahAhYeah       7
# 28       Bubbabear85       8
# 29   OMGNOWAYTHATSBS       8
# ..               ...     ...
# 70      MiracleMan74      19
# 71       KILLer___AJ      20
# 72           G7_WenG      20
# 73              8255      20
# 74              8344      20
# 75          kfox7197      21
# 76       Bob_Roberts      21
# 77       Solomon5968      21
# 78   The_Bryonic_Man      21
# 79      KQ_ZhanDouJi      22
# 80          Elessare      22
# 81    duoduobaby0613      22
# 82           7Burial      22
# 83            INOV77      23
# 84          Azarothe      23
# 85            Faxe99      23
# 86    BLAVKMUSIKPCXB      23
# 87              2092      24
# 88     PannaCottaOVO      24
# 89          D4NoK_Yz      24
# 90     PinaColadaOVO      24
# 91           Fudorin      25
# 92           Mondoja      25
# 93         Dancingly      25
# 94           fuji_-_      26
# 95        Jesse_yjho      26
# 96      HotDoggHands      27
# 97          mattbarn      27
# 98       Diesvtfocus      27
# 99           LDrai29      27
#
# [100 rows x 2 columns]

# %%
# WORKING ON THIS
# get distance between players in the same team 
for team in players_location.teamId.unique()[0:1]:
    data = players_location[players_location.teamId == team]
    players = {}
    for i, player in zip(range(len(data.name.unique())), data.name.unique()):
        players[f'player{i+1}'] = player
    # for time in players_location.time.unique()[0:5]

# %% [markdown]
# ## Player Experience

# %%
url_collectplayer = f"https://api.pubg.com/shards/steam/players/account.c4f12abe7d2143bdbb3d4a9ea4ccd31e"
responsen = requests.get(url_collectplayer, headers=headers)

# %%
player_js=responsen.json()

# %%
player_js
# Out:
# {'data': {'type': 'player',
#   'id': 'account.c4f12abe7d2143bdbb3d4a9ea4ccd31e',
#   'attributes': {'name': 'Dancingly',
#    'stats': None,
#    'titleId': 'bluehole-pubg',
#    'shardId': 'steam',
#    'patchVersion': ''},
#   'relationships': {'assets': {'data': []},
#    'matches': {'data': [{'type': 'match',
#       'id': '8c191e53-ef8c-4282-82a3-ce5345b82047'},
#      {'type': 'match', 'id': '321cfaab-cd33-4914-ad38-581d35dca551'},
#      {'type': 'match', 'id': 'e16a2769-b81c-48e4-b5ea-8ec236fc88f8'},
#      {'type': 'match', 'id': '6e07d321-0acf-4bfc-b5e4-936d59a222a1'},
#      {'type': 'match', 'id': '84a8b27e-b06f-4d13-811a-b6151591c390'},
#      {'type': 'match', 'id': '790effba-baa6-4a42-82c0-1ae26afbb929'},
#      {'type': 'match', 'id': '92118cdd-1281-49f1-a050-c86884efef43'},
#      {'type': 'match', 'id': 'eff196c3-a2e1-4e24-99bb-26573eaa9e64'},
#      {'type': 'match', 'id': '3092aa9e-59a2-4955-ab23-35bd33e3b986'},
#      {'type': 'match', 'id': '0f496a7c-c277-4843-9832-bb0bad7eb139'},
#      {'type': 'match', 'id': 'f1898725-0b15-4655-94fb-0c277edd7c00'},
#      {'type': 'match', 'id': '83ed4abe-342b-411d-adef-23d4ff34b9c1'},
#      {'type': 'match', 'id': 'f58acf51-57e1-4aa1-810e-77c2ed0f1978'},
#      {'type': 'match', 'id': '2cb254b1-2765-40b4-b607-f97dca487cce'},
#      {'type': 'match', 'id': '06533907-3e8d-4f09-aba8-5909bf63a45d'},
#      {'type': 'match', 'id': '2f384489-4fb9-4efe-bca1-96b2db75d2d2'},
#      {'type': 'match', 'id': 'e972eb99-05ae-4361-bf6b-5954b9d375f6'},
#      {'type': 'match', 'id': '8cfd1f16-7af9-43bc-912f-dd0eff0382dc'},
#      {'type': 'match', 'id': '67bfaead-f471-4c51-b5bf-d0be499c12e8'},
#      {'type': 'match', 'id': '4dae3bcc-b7b4-4bef-bf96-377eb97e517c'},
#      {'type': 'match', 'id': '1406acdb-6377-4ecc-b2ce-5e87f7e512b4'},
#      {'type': 'match', 'id': '16afa182-cba4-4b9a-8043-25bbf6697be0'},
#      {'type': 'match', 'id': 'c6498061-5758-4c2b-b6bd-abaf98b618c2'},
#      {'type': 'match', 'id': '9c2176a3-c594-4bc5-af47-12bf71f22778'},
#      {'type': 'match', 'id': 'f11b80f8-1413-4968-8a2c-3a82ce1b3ddc'},
#      {'type': 'match', 'id': '68189eba-e97e-46d6-8456-8eefb0503b85'},
#      {'type': 'match', 'id': '37506643-3116-417c-981a-acbbf845042f'},
#      {'type': 'match', 'id': '33cd7521-4cea-4947-a7e6-6f5496b055bf'},
#      {'type': 'match', 'id': '25628281-f72e-43fa-ac8d-c1e4bd15bd61'},
#      {'type': 'match', 'id': '256f0c77-e640-4679-b06a-d811e1a836e4'},
#      {'type': 'match', 'id': '12ccb2b3-c2d6-4fa1-bdc2-49bff53ecbc2'},
#      {'type': 'match', 'id': 'e876e1ce-3c8b-4c67-b8b0-9d21e0c1da61'},
#      {'type': 'match', 'id': '210458e0-0fe5-46d5-bdec-680e07e9bd64'},
#      {'type': 'match', 'id': '5d93acf8-497f-41f5-9674-ab79c3312f46'},
#      {'type': 'match', 'id': '3ea51750-da51-4ca4-baad-ec2caa74ba13'},
#      {'type': 'match', 'id': 'f7314ce9-a226-4ed9-b8df-c05f06e4b57a'},
#      {'type': 'match', 'id': 'bd894afc-4b14-47df-a98c-6b1ed79e4246'},
#      {'type': 'match', 'id': '6e4f5774-2606-4f18-a514-3ae53059349f'},
#      {'type': 'match', 'id': 'a7c1d13c-c467-49f7-a4a2-a73c2e5190ae'},
#      {'type': 'match', 'id': 'd3c1571d-a7e1-40c3-9115-82ce32a5e743'},
#      {'type': 'match', 'id': '84277939-b2fb-4d56-9014-12aff0c9245a'},
#      {'type': 'match', 'id': '17e7994f-a152-40d4-9cf3-b454584ef04d'},
#      {'type': 'match', 'id': '76c31c4c-8f80-4cc7-8bf0-b49824c64dd3'},
#      {'type': 'match', 'id': '4e38f212-145d-4de1-9ee3-91848ad8bb32'},
#      {'type': 'match', 'id': 'f6e903e9-8f32-43ee-8cb0-84110545d31c'},
#      {'type': 'match', 'id': 'aa04bdcc-d73d-4807-bf8b-17f17252680c'},
#      {'type': 'match', 'id': '7859a959-fed6-478e-8bc5-9ba5c73764ba'},
#      {'type': 'match', 'id': '52d48776-13e2-4639-879a-c7381be3e75b'},
#      {'type': 'match', 'id': '86a19a6a-6413-4228-af02-d79f4ba4ce16'},
#      {'type': 'match', 'id': '00e97e4f-c4c3-47e5-98e6-ff25dd23efe6'},
#      {'type': 'match', 'id': 'dd60c8b3-6f05-4de9-856b-78575309c48a'},
#      {'type': 'match', 'id': '00788c3e-ebc9-4f24-815c-ca1e031779eb'},
#      {'type': 'match', 'id': 'b4d3a599-65e2-4b7b-9ea5-79563534e9c9'},
#      {'type': 'match', 'id': '0b0bd609-e3ac-41d3-8f4b-1d5e4763d5fd'},
#      {'type': 'match', 'id': 'ec464588-8ef5-483c-ba35-279992aa4937'},
#      {'type': 'match', 'id': '33a07894-0b93-4813-acfe-8cd59a8bc7c6'},
#      {'type': 'match', 'id': '594efc0d-4075-41ac-b0fb-41f0e1bd2f60'},
#      {'type': 'match', 'id': 'a550c60e-46d6-447a-a930-93d9d38f50e1'},
#      {'type': 'match', 'id': '50d34174-0bca-48e5-a883-fc117695505c'},
#      {'type': 'match', 'id': 'bd68d9df-08ed-4f5d-ae17-9d81157da5e8'},
#      {'type': 'match', 'id': 'e7f432c8-c953-46bc-ae94-c4576bbca058'},
#      {'type': 'match', 'id': 'b0c3a471-dba2-44cd-bef9-5c74018f4842'},
#      {'type': 'match', 'id': '4607d01f-e61c-4040-9f31-6b2e6390ff77'},
#      {'type': 'match', 'id': '15acbf3f-1283-4015-be6b-27249f3f8c8a'},
#      {'type': 'match', 'id': '7c78cf92-26e7-4fca-9bae-3776ce776f88'},
#      {'type': 'match', 'id': 'cf42d185-402a-4129-a9bf-77cf6df83534'},
#      {'type': 'match', 'id': '377bd21f-1870-4694-b6b9-256537363a78'},
#      {'type': 'match', 'id': '16241f2c-5ef0-4e9c-ae10-ca5cc891fd7a'},
#      {'type': 'match', 'id': '1a855b7e-5c24-4701-9b44-861d713ef1e6'},
#      {'type': 'match', 'id': 'c06f3fc3-f6b3-40ae-84ce-41289aff7cd6'},
#      {'type': 'match', 'id': 'f9883463-2a6f-47ae-9f4f-12fcc1072b5c'},
#      {'type': 'match', 'id': '8498a35e-2aae-4efc-ade8-ba6c20f79343'},
#      {'type': 'match', 'id': '3332575d-2ca0-44a3-aba3-b7a3d1ebd44f'},
#      {'type': 'match', 'id': '127f8b30-d79a-495c-8136-211773b1a078'},
#      {'type': 'match', 'id': '2c772ad5-ceac-4a4e-8564-1e3122dc8ac5'},
#      {'type': 'match', 'id': 'fed98a9a-a5b8-44c0-9a6e-120eaa325b7e'},
#      {'type': 'match', 'id': 'ccce8452-e212-4cfe-8081-4fe654fca14a'},
#      {'type': 'match', 'id': 'e781abe0-30de-4699-976f-535ce80e7504'},
#      {'type': 'match', 'id': '8df69693-9e5f-4fad-861d-762f392bd3d2'},
#      {'type': 'match', 'id': '4222a2af-9c44-4373-990b-3d3e5e7ccd4c'},
#      {'type': 'match', 'id': '838a9ad2-dba5-494d-907b-fc05d3c82ac0'},
#      {'type': 'match', 'id': '48afe02d-cf1c-4ad9-903a-47dac8f598c9'},
#      {'type': 'match', 'id': 'd519fca8-11fc-4a0a-b584-d9e3224ec675'}]}},
#   'links': {'self': 'https://api.playbattlegrounds.com/shards/steam/players/account.c4f12abe7d2143bdbb3d4a9ea4ccd31e',
#    'schema': ''}},
#  'links': {'self': 'https://api.pubg.com/shards/steam/players/account.c4f12abe7d2143bdbb3d4a9ea4ccd31e'},
#  'meta': {}}

# %%
# collect the match data of one match. We need this to get the assets id, needed to get the full telemetry data
url_collectassetsid = f"https://api.pubg.com/shards/pc/matches/4c76d82b-90f7-4fd1-9ceb-97b99347e94e"
response2 = requests.get(url_collectassetsid, headers=headers)

# %%
player=response2.json()

# %%
player_df=json_normalize(player["included"])

# %%
player_df.columns
# Out:
# Index(['attributes.URL', 'attributes.actor', 'attributes.createdAt',
#        'attributes.description', 'attributes.name', 'attributes.shardId',
#        'attributes.stats.DBNOs', 'attributes.stats.assists',
#        'attributes.stats.boosts', 'attributes.stats.damageDealt',
#        'attributes.stats.deathType', 'attributes.stats.headshotKills',
#        'attributes.stats.heals', 'attributes.stats.killPlace',
#        'attributes.stats.killStreaks', 'attributes.stats.kills',
#        'attributes.stats.longestKill', 'attributes.stats.name',
#        'attributes.stats.playerId', 'attributes.stats.rank',
#        'attributes.stats.revives', 'attributes.stats.rideDistance',
#        'attributes.stats.roadKills', 'attributes.stats.swimDistance',
#        'attributes.stats.teamId', 'attributes.stats.teamKills',
#        'attributes.stats.timeSurvived', 'attributes.stats.vehicleDestroys',
#        'attributes.stats.walkDistance', 'attributes.stats.weaponsAcquired',
#        'attributes.stats.winPlace', 'attributes.won', 'id',
#        'relationships.participants.data', 'relationships.team.data', 'type'],
#       dtype='object')

# %%
player_df = player_df[['attributes.stats.killPlace','attributes.stats.kills',"attributes.stats.killStreaks","attributes.stats.rank",'attributes.stats.weaponsAcquired',"attributes.stats.winPlace","attributes.stats.teamId","attributes.stats.playerId","attributes.stats.assists","attributes.stats.damageDealt"]]

# %%
#what if we look at damagedealt and win place if both high then the player is experienced cause he faught more but survived
player_df
# Out:
#     attributes.stats.killPlace  attributes.stats.kills  \
# 0                         39.0                     0.0
# 1                         50.0                     0.0
# 2                         40.0                     0.0
# 3                         36.0                     0.0
# 5                         32.0                     0.0
# 6                         24.0                     1.0
# 7                         69.0                     0.0
# 8                         63.0                     0.0
# 9                          7.0                     5.0
# 10                        28.0                     1.0
# 11                        41.0                     0.0
# 12                        45.0                     0.0
# 14                         5.0                     5.0
# 15                        20.0                     1.0
# 17                        10.0                     3.0
# 18                        37.0                     0.0
# 19                        67.0                     0.0
# 20                        44.0                     0.0
# 21                        43.0                     0.0
# 22                        13.0                     2.0
# 23                        68.0                     0.0
# 24                        22.0                     1.0
# 27                        76.0                     0.0
# 29                         2.0                     6.0
# 30                         4.0                     6.0
# 31                         9.0                     3.0
# 32                        26.0                     1.0
# 33                        64.0                     0.0
# 34                        73.0                     0.0
# 36                        55.0                     0.0
# ..                         ...                     ...
# 58                        53.0                     0.0
# 59                        12.0                     2.0
# 60                        47.0                     0.0
# 61                        70.0                     0.0
# 64                        59.0                     0.0
# 66                        19.0                     1.0
# 67                        18.0                     1.0
# 68                        42.0                     0.0
# 69                        46.0                     0.0
# 70                        17.0                     1.0
# 71                        75.0                     0.0
# 75                        48.0                     0.0
# 76                        15.0                     2.0
# 77                        16.0                     1.0
# 78                        23.0                     1.0
# 79                        66.0                     0.0
# 80                        58.0                     0.0
# 81                         8.0                     3.0
# 84                        56.0                     0.0
# 85                        34.0                     0.0
# 86                         3.0                     6.0
# 88                        38.0                     0.0
# 89                        14.0                     2.0
# 90                        57.0                     0.0
# 91                        29.0                     0.0
# 92                        49.0                     0.0
# 93                        61.0                     0.0
# 94                        71.0                     0.0
# 95                        72.0                     0.0
# 96                        60.0                     0.0
#
#     attributes.stats.killStreaks  attributes.stats.rank  \
# 0                            0.0                    NaN
# 1                            0.0                    NaN
# 2                            0.0                    NaN
# 3                            0.0                    NaN
# 5                            0.0                    NaN
# 6                            1.0                    NaN
# 7                            0.0                    NaN
# 8                            0.0                    NaN
# 9                            2.0                    NaN
# 10                           1.0                    NaN
# 11                           0.0                    NaN
# 12                           0.0                    NaN
# 14                           2.0                    NaN
# 15                           1.0                    NaN
# 17                           2.0                    NaN
# 18                           0.0                    NaN
# 19                           0.0                    NaN
# 20                           0.0                    NaN
# 21                           0.0                    NaN
# 22                           2.0                    NaN
# 23                           0.0                    NaN
# 24                           1.0                    NaN
# 27                           0.0                    NaN
# 29                           1.0                    NaN
# 30                           2.0                    NaN
# 31                           1.0                    NaN
# 32                           1.0                    NaN
# 33                           0.0                    NaN
# 34                           0.0                    NaN
# 36                           0.0                    NaN
# ..                           ...                    ...
# 58                           0.0                    NaN
# 59                           2.0                    NaN
# 60                           0.0                    NaN
# 61                           0.0                    NaN
# 64                           0.0                    NaN
# 66                           1.0                    NaN
# 67                           1.0                    NaN
# 68                           0.0                    NaN
# 69                           0.0                    NaN
# 70                           1.0                    NaN
# 71                           0.0                    NaN
# 75                           0.0                    NaN
# 76                           2.0                    NaN
# 77                           1.0                    NaN
# 78                           1.0                    NaN
# 79                           0.0                    NaN
# 80                           0.0                    NaN
# 81                           3.0                    NaN
# 84                           0.0                    NaN
# 85                           0.0                    NaN
# 86                           2.0                    NaN
# 88                           0.0                    NaN
# 89                           1.0                    NaN
# 90                           0.0                    NaN
# 91                           0.0                    NaN
# 92                           0.0                    NaN
# 93                           0.0                    NaN
# 94                           0.0                    NaN
# 95                           0.0                    NaN
# 96                           0.0                    NaN
#
#     attributes.stats.weaponsAcquired  attributes.stats.winPlace  \
# 0                                4.0                       10.0
# 1                                7.0                       14.0
# 2                                8.0                       11.0
# 3                                5.0                        7.0
# 5                               10.0                        3.0
# 6                                3.0                       15.0
# 7                                3.0                       19.0
# 8                                4.0                       17.0
# 9                                9.0                       13.0
# 10                               2.0                       20.0
# 11                               5.0                       11.0
# 12                               3.0                       12.0
# 14                               8.0                        1.0
# 15                               8.0                        8.0
# 17                               3.0                        7.0
# 18                               5.0                        7.0
# 19                               1.0                       18.0
# 20                               4.0                       12.0
# 21                               8.0                       12.0
# 22                               5.0                        8.0
# 23                               2.0                       18.0
# 24                              11.0                       12.0
# 27                               0.0                       21.0
# 29                               4.0                        1.0
# 30                               7.0                       13.0
# 31                               9.0                        5.0
# 32                               2.0                       19.0
# 33                               3.0                       17.0
# 34                               1.0                       20.0
# 36                               5.0                       16.0
# ..                               ...                        ...
# 58                               6.0                       15.0
# 59                               5.0                        8.0
# 60                               4.0                       12.0
# 61                               3.0                       19.0
# 64                               3.0                       17.0
# 66                               6.0                        4.0
# 67                              11.0                        4.0
# 68                               5.0                       12.0
# 69                              12.0                       12.0
# 70                               2.0                        3.0
# 71                               0.0                       21.0
# 75                               0.0                       13.0
# 76                               3.0                       11.0
# 77                               3.0                        2.0
# 78                               6.0                       15.0
# 79                               2.0                       18.0
# 80                               5.0                       17.0
# 81                               4.0                        2.0
# 84                               2.0                       16.0
# 85                               6.0                        6.0
# 86                              10.0                        5.0
# 88                               5.0                       10.0
# 89                               5.0                        9.0
# 90                               1.0                       16.0
# 91                               6.0                        1.0
# 92                               6.0                       14.0
# 93                               4.0                       17.0
# 94                               2.0                       20.0
# 95                               0.0                       20.0
# 96                               7.0                       17.0
#
#     attributes.stats.teamId                                 accountId  \
# 0                       NaN  account.6edabfe353ef4a12835f740fcf198c76
# 1                       NaN  account.ffad5b1280314f6dab6a48d6cf8cdf54
# 2                       NaN  account.c4f12abe7d2143bdbb3d4a9ea4ccd31e
# 3                       NaN  account.749c1f3bc22841ccb17fd9aa3e65bccf
# 5                       NaN  account.4b3dcc0c663846c59981fb53f61eaf19
# 6                       NaN  account.0d8958712dab4d8da4ac5183f2c2385a
# 7                       NaN  account.e4464ed974c441bbaf5d75342810bcad
# 8                       NaN  account.eedb2af394cf40c2bc5809264a43df99
# 9                       NaN  account.93785a3f37e041ed8fe9221f9e8b9ca5
# 10                      NaN  account.f41a6e2001664439b818784d15ffc124
# 11                      NaN  account.6122a9daf65d448b930772a88651b53c
# 12                      NaN  account.1f660c04029a489d92822e0282be22a0
# 14                      NaN  account.9f0da77bfcab40149791be996d9e2e59
# 15                      NaN  account.542278ff8be14ac08a1b3de2877b4a7c
# 17                      NaN  account.54a138a899ea43919a51de65323d9287
# 18                      NaN  account.50adcc0db4de465aa9ae3b726498f5c7
# 19                      NaN  account.c3baffb7b59f424cb8e0234e8a3d5542
# 20                      NaN  account.0261932f6e834d23a1e5af9641e81a07
# 21                      NaN  account.1c38aec23e5e4a458a210a6d16c8eca5
# 22                      NaN  account.79c2f8876c4840a3a8de76d5be3ddf71
# 23                      NaN  account.b2875d9ab5484d1aa41cbf9ba8e8ae2e
# 24                      NaN  account.1d52dff3cfbf4e5b95020a71f84f0c63
# 27                      NaN  account.e60bd0f0cc8040b6a5c0a49d5ad1cdc3
# 29                      NaN  account.e4d70b1f31ce451fa55e46eb95278715
# 30                      NaN  account.c2200a42a77349e582788e9a6081aeb4
# 31                      NaN  account.ff1ec4f49b224de8a8107bc73fae0081
# 32                      NaN  account.4b0e221bb7b441218123956666fcc5c5
# 33                      NaN  account.39ce2adafa4340fca6a983d59ed8a307
# 34                      NaN  account.aae7ef8724284447953034a9ccbe89aa
# 36                      NaN  account.385a9f5436af46cf968ffff7219bc696
# ..                      ...                                       ...
# 58                      NaN  account.d22cd0ef458c411caef12c9f5db9ea27
# 59                      NaN  account.79208548b044413bb761d34f19783a49
# 60                      NaN  account.bdc00b85422c4807bdc3de91d56be5d6
# 61                      NaN  account.62d34dd73cf54e41b2447d172c9609f3
# 64                      NaN  account.d9863a055ddd4cf8b192fc7a094692c3
# 66                      NaN  account.a2fd712cae2241179afc28e05170e306
# 67                      NaN  account.6161f979fe184888bb9b733cc18960c7
# 68                      NaN  account.3a5ff17681354a0982a7e8caa7b74b17
# 69                      NaN  account.c7c9bf6dae124f5cb98cf581e0ce2c6d
# 70                      NaN  account.5698432e17984521aad0f1c62923d24a
# 71                      NaN  account.24b7ed5249a44a968e20d5b3387a951c
# 75                      NaN  account.c3d2339935824cdc9e55f9c7b575e355
# 76                      NaN  account.430e7112176d4d849d2a873e19ec199e
# 77                      NaN  account.dfdb53bf20534cffa29b7207076923d2
# 78                      NaN  account.e5be34fde69841ab9cf6b6681482d9d2
# 79                      NaN  account.c9c4480e5fa348dfa7d1a14a29ba87dc
# 80                      NaN  account.1b9f91fb61504402b9774fcfa430e57e
# 81                      NaN  account.22528554f5594e39aa5f7c150d7a97a0
# 84                      NaN  account.1b8f4326cdb44cd6ac1c99a3d2182e5d
# 85                      NaN  account.038f96e8563f4e03af57d48c684d7773
# 86                      NaN  account.824eb122d6a543d9a0e372ffc9657ecd
# 88                      NaN  account.98a361b6ee494c9c8ae2c3f739415a84
# 89                      NaN  account.fc9fa62d67d84a33a25f29383d392e94
# 90                      NaN  account.0fdde91555614333a012cc93f30d1372
# 91                      NaN  account.acd6626ba55f4f128e3395a627b4d2da
# 92                      NaN  account.c54691c19cfd49c1bbd3ce003104dc49
# 93                      NaN  account.7fc7e4f15d65427790dea654a9b86c69
# 94                      NaN  account.6b46d60583254839bf6e8c3df814f115
# 95                      NaN  account.154d4fd125a348e9a1f8df2daaabd9cb
# 96                      NaN  account.1093943b709c4a39b37343249ac8a65d
#
#     attributes.stats.assists  attributes.stats.damageDealt
# 0                        0.0                     19.350000
# 1                        0.0                     23.109653
# 2                        0.0                      0.000000
# 3                        0.0                     27.060001
# 5                        0.0                    176.007930
# 6                        0.0                    157.175480
# 7                        0.0                      0.000000
# 8                        0.0                      0.000000
# 9                        2.0                    477.838100
# 10                       0.0                     89.200000
# 11                       0.0                     93.738030
# 12                       0.0                     21.073034
# 14                       0.0                    670.353000
# 15                       3.0                    120.778100
# 17                       0.0                    196.372500
# 18                       0.0                      0.000000
# 19                       0.0                     22.140001
# 20                       0.0                     44.769850
# 21                       0.0                     75.784970
# 22                       1.0                    333.095550
# 23                       0.0                      0.000000
# 24                       0.0                    156.510000
# 27                       0.0                      0.000000
# 29                       1.0                    671.233460
# 30                       1.0                    704.756800
# 31                       0.0                    462.771060
# 32                       0.0                    195.576160
# 33                       0.0                    185.075000
# 34                       0.0                      0.000000
# 36                       0.0                      0.000000
# ..                       ...                           ...
# 58                       0.0                      0.000000
# 59                       1.0                    191.621580
# 60                       0.0                     57.553265
# 61                       0.0                      0.000000
# 64                       0.0                      0.000000
# 66                       0.0                     26.599998
# 67                       1.0                    114.142080
# 68                       0.0                     55.559730
# 69                       0.0                      0.000000
# 70                       0.0                     70.571210
# 71                       0.0                      0.000000
# 75                       0.0                      0.000000
# 76                       0.0                    197.813370
# 77                       0.0                     12.000000
# 78                       0.0                    100.000000
# 79                       0.0                      0.000000
# 80                       0.0                     35.386290
# 81                       1.0                    542.050500
# 84                       0.0                      0.000000
# 85                       0.0                    143.422990
# 86                       0.0                    700.268700
# 88                       0.0                     21.276686
# 89                       0.0                    286.086460
# 90                       0.0                     77.080000
# 91                       2.0                     19.823332
# 92                       0.0                      0.000000
# 93                       0.0                     28.700000
# 94                       0.0                     57.400000
# 95                       1.0                     10.800000
# 96                       0.0                     28.202602
#
# [76 rows x 10 columns]

# %%
player_df= player_df.rename(columns={'attributes.stats.playerId': 'accountId'})
player_df = player_df[player_df['accountId'].notna()]
player_df
# Out:
#     attributes.stats.killPlace  attributes.stats.kills  \
# 0                         39.0                     0.0
# 1                         50.0                     0.0
# 2                         40.0                     0.0
# 3                         36.0                     0.0
# 5                         32.0                     0.0
# 6                         24.0                     1.0
# 7                         69.0                     0.0
# 8                         63.0                     0.0
# 9                          7.0                     5.0
# 10                        28.0                     1.0
# 11                        41.0                     0.0
# 12                        45.0                     0.0
# 14                         5.0                     5.0
# 15                        20.0                     1.0
# 17                        10.0                     3.0
# 18                        37.0                     0.0
# 19                        67.0                     0.0
# 20                        44.0                     0.0
# 21                        43.0                     0.0
# 22                        13.0                     2.0
# 23                        68.0                     0.0
# 24                        22.0                     1.0
# 27                        76.0                     0.0
# 29                         2.0                     6.0
# 30                         4.0                     6.0
# 31                         9.0                     3.0
# 32                        26.0                     1.0
# 33                        64.0                     0.0
# 34                        73.0                     0.0
# 36                        55.0                     0.0
# ..                         ...                     ...
# 58                        53.0                     0.0
# 59                        12.0                     2.0
# 60                        47.0                     0.0
# 61                        70.0                     0.0
# 64                        59.0                     0.0
# 66                        19.0                     1.0
# 67                        18.0                     1.0
# 68                        42.0                     0.0
# 69                        46.0                     0.0
# 70                        17.0                     1.0
# 71                        75.0                     0.0
# 75                        48.0                     0.0
# 76                        15.0                     2.0
# 77                        16.0                     1.0
# 78                        23.0                     1.0
# 79                        66.0                     0.0
# 80                        58.0                     0.0
# 81                         8.0                     3.0
# 84                        56.0                     0.0
# 85                        34.0                     0.0
# 86                         3.0                     6.0
# 88                        38.0                     0.0
# 89                        14.0                     2.0
# 90                        57.0                     0.0
# 91                        29.0                     0.0
# 92                        49.0                     0.0
# 93                        61.0                     0.0
# 94                        71.0                     0.0
# 95                        72.0                     0.0
# 96                        60.0                     0.0
#
#     attributes.stats.killStreaks  attributes.stats.rank  \
# 0                            0.0                    NaN
# 1                            0.0                    NaN
# 2                            0.0                    NaN
# 3                            0.0                    NaN
# 5                            0.0                    NaN
# 6                            1.0                    NaN
# 7                            0.0                    NaN
# 8                            0.0                    NaN
# 9                            2.0                    NaN
# 10                           1.0                    NaN
# 11                           0.0                    NaN
# 12                           0.0                    NaN
# 14                           2.0                    NaN
# 15                           1.0                    NaN
# 17                           2.0                    NaN
# 18                           0.0                    NaN
# 19                           0.0                    NaN
# 20                           0.0                    NaN
# 21                           0.0                    NaN
# 22                           2.0                    NaN
# 23                           0.0                    NaN
# 24                           1.0                    NaN
# 27                           0.0                    NaN
# 29                           1.0                    NaN
# 30                           2.0                    NaN
# 31                           1.0                    NaN
# 32                           1.0                    NaN
# 33                           0.0                    NaN
# 34                           0.0                    NaN
# 36                           0.0                    NaN
# ..                           ...                    ...
# 58                           0.0                    NaN
# 59                           2.0                    NaN
# 60                           0.0                    NaN
# 61                           0.0                    NaN
# 64                           0.0                    NaN
# 66                           1.0                    NaN
# 67                           1.0                    NaN
# 68                           0.0                    NaN
# 69                           0.0                    NaN
# 70                           1.0                    NaN
# 71                           0.0                    NaN
# 75                           0.0                    NaN
# 76                           2.0                    NaN
# 77                           1.0                    NaN
# 78                           1.0                    NaN
# 79                           0.0                    NaN
# 80                           0.0                    NaN
# 81                           3.0                    NaN
# 84                           0.0                    NaN
# 85                           0.0                    NaN
# 86                           2.0                    NaN
# 88                           0.0                    NaN
# 89                           1.0                    NaN
# 90                           0.0                    NaN
# 91                           0.0                    NaN
# 92                           0.0                    NaN
# 93                           0.0                    NaN
# 94                           0.0                    NaN
# 95                           0.0                    NaN
# 96                           0.0                    NaN
#
#     attributes.stats.weaponsAcquired  attributes.stats.winPlace  \
# 0                                4.0                       10.0
# 1                                7.0                       14.0
# 2                                8.0                       11.0
# 3                                5.0                        7.0
# 5                               10.0                        3.0
# 6                                3.0                       15.0
# 7                                3.0                       19.0
# 8                                4.0                       17.0
# 9                                9.0                       13.0
# 10                               2.0                       20.0
# 11                               5.0                       11.0
# 12                               3.0                       12.0
# 14                               8.0                        1.0
# 15                               8.0                        8.0
# 17                               3.0                        7.0
# 18                               5.0                        7.0
# 19                               1.0                       18.0
# 20                               4.0                       12.0
# 21                               8.0                       12.0
# 22                               5.0                        8.0
# 23                               2.0                       18.0
# 24                              11.0                       12.0
# 27                               0.0                       21.0
# 29                               4.0                        1.0
# 30                               7.0                       13.0
# 31                               9.0                        5.0
# 32                               2.0                       19.0
# 33                               3.0                       17.0
# 34                               1.0                       20.0
# 36                               5.0                       16.0
# ..                               ...                        ...
# 58                               6.0                       15.0
# 59                               5.0                        8.0
# 60                               4.0                       12.0
# 61                               3.0                       19.0
# 64                               3.0                       17.0
# 66                               6.0                        4.0
# 67                              11.0                        4.0
# 68                               5.0                       12.0
# 69                              12.0                       12.0
# 70                               2.0                        3.0
# 71                               0.0                       21.0
# 75                               0.0                       13.0
# 76                               3.0                       11.0
# 77                               3.0                        2.0
# 78                               6.0                       15.0
# 79                               2.0                       18.0
# 80                               5.0                       17.0
# 81                               4.0                        2.0
# 84                               2.0                       16.0
# 85                               6.0                        6.0
# 86                              10.0                        5.0
# 88                               5.0                       10.0
# 89                               5.0                        9.0
# 90                               1.0                       16.0
# 91                               6.0                        1.0
# 92                               6.0                       14.0
# 93                               4.0                       17.0
# 94                               2.0                       20.0
# 95                               0.0                       20.0
# 96                               7.0                       17.0
#
#     attributes.stats.teamId                                 accountId  \
# 0                       NaN  account.6edabfe353ef4a12835f740fcf198c76
# 1                       NaN  account.ffad5b1280314f6dab6a48d6cf8cdf54
# 2                       NaN  account.c4f12abe7d2143bdbb3d4a9ea4ccd31e
# 3                       NaN  account.749c1f3bc22841ccb17fd9aa3e65bccf
# 5                       NaN  account.4b3dcc0c663846c59981fb53f61eaf19
# 6                       NaN  account.0d8958712dab4d8da4ac5183f2c2385a
# 7                       NaN  account.e4464ed974c441bbaf5d75342810bcad
# 8                       NaN  account.eedb2af394cf40c2bc5809264a43df99
# 9                       NaN  account.93785a3f37e041ed8fe9221f9e8b9ca5
# 10                      NaN  account.f41a6e2001664439b818784d15ffc124
# 11                      NaN  account.6122a9daf65d448b930772a88651b53c
# 12                      NaN  account.1f660c04029a489d92822e0282be22a0
# 14                      NaN  account.9f0da77bfcab40149791be996d9e2e59
# 15                      NaN  account.542278ff8be14ac08a1b3de2877b4a7c
# 17                      NaN  account.54a138a899ea43919a51de65323d9287
# 18                      NaN  account.50adcc0db4de465aa9ae3b726498f5c7
# 19                      NaN  account.c3baffb7b59f424cb8e0234e8a3d5542
# 20                      NaN  account.0261932f6e834d23a1e5af9641e81a07
# 21                      NaN  account.1c38aec23e5e4a458a210a6d16c8eca5
# 22                      NaN  account.79c2f8876c4840a3a8de76d5be3ddf71
# 23                      NaN  account.b2875d9ab5484d1aa41cbf9ba8e8ae2e
# 24                      NaN  account.1d52dff3cfbf4e5b95020a71f84f0c63
# 27                      NaN  account.e60bd0f0cc8040b6a5c0a49d5ad1cdc3
# 29                      NaN  account.e4d70b1f31ce451fa55e46eb95278715
# 30                      NaN  account.c2200a42a77349e582788e9a6081aeb4
# 31                      NaN  account.ff1ec4f49b224de8a8107bc73fae0081
# 32                      NaN  account.4b0e221bb7b441218123956666fcc5c5
# 33                      NaN  account.39ce2adafa4340fca6a983d59ed8a307
# 34                      NaN  account.aae7ef8724284447953034a9ccbe89aa
# 36                      NaN  account.385a9f5436af46cf968ffff7219bc696
# ..                      ...                                       ...
# 58                      NaN  account.d22cd0ef458c411caef12c9f5db9ea27
# 59                      NaN  account.79208548b044413bb761d34f19783a49
# 60                      NaN  account.bdc00b85422c4807bdc3de91d56be5d6
# 61                      NaN  account.62d34dd73cf54e41b2447d172c9609f3
# 64                      NaN  account.d9863a055ddd4cf8b192fc7a094692c3
# 66                      NaN  account.a2fd712cae2241179afc28e05170e306
# 67                      NaN  account.6161f979fe184888bb9b733cc18960c7
# 68                      NaN  account.3a5ff17681354a0982a7e8caa7b74b17
# 69                      NaN  account.c7c9bf6dae124f5cb98cf581e0ce2c6d
# 70                      NaN  account.5698432e17984521aad0f1c62923d24a
# 71                      NaN  account.24b7ed5249a44a968e20d5b3387a951c
# 75                      NaN  account.c3d2339935824cdc9e55f9c7b575e355
# 76                      NaN  account.430e7112176d4d849d2a873e19ec199e
# 77                      NaN  account.dfdb53bf20534cffa29b7207076923d2
# 78                      NaN  account.e5be34fde69841ab9cf6b6681482d9d2
# 79                      NaN  account.c9c4480e5fa348dfa7d1a14a29ba87dc
# 80                      NaN  account.1b9f91fb61504402b9774fcfa430e57e
# 81                      NaN  account.22528554f5594e39aa5f7c150d7a97a0
# 84                      NaN  account.1b8f4326cdb44cd6ac1c99a3d2182e5d
# 85                      NaN  account.038f96e8563f4e03af57d48c684d7773
# 86                      NaN  account.824eb122d6a543d9a0e372ffc9657ecd
# 88                      NaN  account.98a361b6ee494c9c8ae2c3f739415a84
# 89                      NaN  account.fc9fa62d67d84a33a25f29383d392e94
# 90                      NaN  account.0fdde91555614333a012cc93f30d1372
# 91                      NaN  account.acd6626ba55f4f128e3395a627b4d2da
# 92                      NaN  account.c54691c19cfd49c1bbd3ce003104dc49
# 93                      NaN  account.7fc7e4f15d65427790dea654a9b86c69
# 94                      NaN  account.6b46d60583254839bf6e8c3df814f115
# 95                      NaN  account.154d4fd125a348e9a1f8df2daaabd9cb
# 96                      NaN  account.1093943b709c4a39b37343249ac8a65d
#
#     attributes.stats.assists  attributes.stats.damageDealt
# 0                        0.0                     19.350000
# 1                        0.0                     23.109653
# 2                        0.0                      0.000000
# 3                        0.0                     27.060001
# 5                        0.0                    176.007930
# 6                        0.0                    157.175480
# 7                        0.0                      0.000000
# 8                        0.0                      0.000000
# 9                        2.0                    477.838100
# 10                       0.0                     89.200000
# 11                       0.0                     93.738030
# 12                       0.0                     21.073034
# 14                       0.0                    670.353000
# 15                       3.0                    120.778100
# 17                       0.0                    196.372500
# 18                       0.0                      0.000000
# 19                       0.0                     22.140001
# 20                       0.0                     44.769850
# 21                       0.0                     75.784970
# 22                       1.0                    333.095550
# 23                       0.0                      0.000000
# 24                       0.0                    156.510000
# 27                       0.0                      0.000000
# 29                       1.0                    671.233460
# 30                       1.0                    704.756800
# 31                       0.0                    462.771060
# 32                       0.0                    195.576160
# 33                       0.0                    185.075000
# 34                       0.0                      0.000000
# 36                       0.0                      0.000000
# ..                       ...                           ...
# 58                       0.0                      0.000000
# 59                       1.0                    191.621580
# 60                       0.0                     57.553265
# 61                       0.0                      0.000000
# 64                       0.0                      0.000000
# 66                       0.0                     26.599998
# 67                       1.0                    114.142080
# 68                       0.0                     55.559730
# 69                       0.0                      0.000000
# 70                       0.0                     70.571210
# 71                       0.0                      0.000000
# 75                       0.0                      0.000000
# 76                       0.0                    197.813370
# 77                       0.0                     12.000000
# 78                       0.0                    100.000000
# 79                       0.0                      0.000000
# 80                       0.0                     35.386290
# 81                       1.0                    542.050500
# 84                       0.0                      0.000000
# 85                       0.0                    143.422990
# 86                       0.0                    700.268700
# 88                       0.0                     21.276686
# 89                       0.0                    286.086460
# 90                       0.0                     77.080000
# 91                       2.0                     19.823332
# 92                       0.0                      0.000000
# 93                       0.0                     28.700000
# 94                       0.0                     57.400000
# 95                       1.0                     10.800000
# 96                       0.0                     28.202602
#
# [76 rows x 10 columns]

# %%
result = pd.merge(player_df,
                 data[['teamId', 'ranking','accountId']],
                 on='accountId')
result = result.drop_duplicates()

# %%
rankings=result.groupby('teamId')['ranking'].agg(pd.Series.idxmax)
df_rank = pd.merge(result, rankings, on=['teamId'], how='left')
df_rank=df_rank.drop(["ranking_x",'index',"attributes.stats.teamId","attributes.stats.rank"],axis=1)

# %%
df_rank=df_rank.drop_duplicates()

# %%
df_rank[df_rank['teamId']==21]
# Out:
#     attributes.stats.killPlace  attributes.stats.kills  \
# 0                         39.0                     0.0
# 58                        21.0                     1.0
# 72                        53.0                     0.0
# 94                        23.0                     1.0
#
#     attributes.stats.killStreaks  attributes.stats.weaponsAcquired  \
# 0                            0.0                               4.0
# 58                           1.0                               9.0
# 72                           0.0                               6.0
# 94                           1.0                               6.0
#
#     attributes.stats.winPlace                                 accountId  \
# 0                        10.0  account.6edabfe353ef4a12835f740fcf198c76
# 58                       10.0  account.aaccc75f95d5416ebf19960691dc13c6
# 72                       15.0  account.d22cd0ef458c411caef12c9f5db9ea27
# 94                       15.0  account.e5be34fde69841ab9cf6b6681482d9d2
#
#     attributes.stats.assists  attributes.stats.damageDealt  teamId  ranking_y
# 0                        0.0                      19.35000      21         59
# 58                       2.0                     327.57547      21         59
# 72                       0.0                       0.00000      21         59
# 94                       0.0                     100.00000      21         59

# %%
pg.corr(x=player_df['attributes.stats.killPlace'], y=player_df['attributes.stats.damageDealt'])
pg.corr(x=player_df['attributes.stats.kills'], y=player_df['attributes.stats.damageDealt'])
pg.corr(x=player_df['attributes.stats.kills'], y=player_df['attributes.stats.damageDealt'])
# Out:
#           n      r          CI95%     r2  adj_r2         p-val       BF10  \
# pearson  76 -0.725  [-0.82, -0.6]  0.526   0.513  1.306762e-13  6.763e+10
#
#          power
# pearson    1.0

# %%
player_df.corr()
# Out:
#                                   attributes.stats.killPlace  \
# attributes.stats.killPlace                          1.000000
# attributes.stats.kills                             -0.742408
# attributes.stats.killStreaks                       -0.804888
# attributes.stats.rank                                    NaN
# attributes.stats.weaponsAcquired                   -0.501652
# attributes.stats.winPlace                           0.761403
# attributes.stats.teamId                                  NaN
# attributes.stats.assists                           -0.416559
# attributes.stats.damageDealt                       -0.725016
#
#                                   attributes.stats.kills  \
# attributes.stats.killPlace                     -0.742408
# attributes.stats.kills                          1.000000
# attributes.stats.killStreaks                    0.778768
# attributes.stats.rank                                NaN
# attributes.stats.weaponsAcquired                0.276380
# attributes.stats.winPlace                      -0.458237
# attributes.stats.teamId                              NaN
# attributes.stats.assists                        0.416783
# attributes.stats.damageDealt                    0.934800
#
#                                   attributes.stats.killStreaks  \
# attributes.stats.killPlace                           -0.804888
# attributes.stats.kills                                0.778768
# attributes.stats.killStreaks                          1.000000
# attributes.stats.rank                                      NaN
# attributes.stats.weaponsAcquired                      0.252585
# attributes.stats.winPlace                            -0.430412
# attributes.stats.teamId                                    NaN
# attributes.stats.assists                              0.396632
# attributes.stats.damageDealt                          0.742437
#
#                                   attributes.stats.rank  \
# attributes.stats.killPlace                          NaN
# attributes.stats.kills                              NaN
# attributes.stats.killStreaks                        NaN
# attributes.stats.rank                               NaN
# attributes.stats.weaponsAcquired                    NaN
# attributes.stats.winPlace                           NaN
# attributes.stats.teamId                             NaN
# attributes.stats.assists                            NaN
# attributes.stats.damageDealt                        NaN
#
#                                   attributes.stats.weaponsAcquired  \
# attributes.stats.killPlace                               -0.501652
# attributes.stats.kills                                    0.276380
# attributes.stats.killStreaks                              0.252585
# attributes.stats.rank                                          NaN
# attributes.stats.weaponsAcquired                          1.000000
# attributes.stats.winPlace                                -0.488500
# attributes.stats.teamId                                        NaN
# attributes.stats.assists                                  0.193025
# attributes.stats.damageDealt                              0.353220
#
#                                   attributes.stats.winPlace  \
# attributes.stats.killPlace                         0.761403
# attributes.stats.kills                            -0.458237
# attributes.stats.killStreaks                      -0.430412
# attributes.stats.rank                                   NaN
# attributes.stats.weaponsAcquired                  -0.488500
# attributes.stats.winPlace                          1.000000
# attributes.stats.teamId                                 NaN
# attributes.stats.assists                          -0.351103
# attributes.stats.damageDealt                      -0.507016
#
#                                   attributes.stats.teamId  \
# attributes.stats.killPlace                            NaN
# attributes.stats.kills                                NaN
# attributes.stats.killStreaks                          NaN
# attributes.stats.rank                                 NaN
# attributes.stats.weaponsAcquired                      NaN
# attributes.stats.winPlace                             NaN
# attributes.stats.teamId                               NaN
# attributes.stats.assists                              NaN
# attributes.stats.damageDealt                          NaN
#
#                                   attributes.stats.assists  \
# attributes.stats.killPlace                       -0.416559
# attributes.stats.kills                            0.416783
# attributes.stats.killStreaks                      0.396632
# attributes.stats.rank                                  NaN
# attributes.stats.weaponsAcquired                  0.193025
# attributes.stats.winPlace                        -0.351103
# attributes.stats.teamId                                NaN
# attributes.stats.assists                          1.000000
# attributes.stats.damageDealt                      0.406409
#
#                                   attributes.stats.damageDealt
# attributes.stats.killPlace                           -0.725016
# attributes.stats.kills                                0.934800
# attributes.stats.killStreaks                          0.742437
# attributes.stats.rank                                      NaN
# attributes.stats.weaponsAcquired                      0.353220
# attributes.stats.winPlace                            -0.507016
# attributes.stats.teamId                                    NaN
# attributes.stats.assists                              0.406409
# attributes.stats.damageDealt                          1.000000

# %%
# RUN THIS CELL TO WORK WITH THE FILE UPLOADED IN THE REPOSITORY
# read files extracted from this as DataFrame
with open('telemetry_data/2020-04-09/pc/4c76d82b-90f7-4fd1-9ceb-97b99347e94e.json', 'r') as file:
    json_data = file.read()
    file.close()
data = []
for i in json.loads(json_data):
    if i["_T"] in ("LogPlayerPosition", "LogParachuteLanding"):
        data.append(i)

# %%
# get player information
from pandas.io.json import json_normalize
data = pd.concat([data, json_normalize(data['character'])], axis=1).drop(['character', 'zone'], axis=1)
data.head()

# %% [markdown]
# ## Export to .csv

# %%
# export match telemetry data into .csv format
data.to_csv(path_or_buf=f'{matchid}.csv')
